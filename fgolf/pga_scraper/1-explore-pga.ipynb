# %%
import requests
import json

# %% [markdown]
# ## Get tournament ids

# %%
tourneys = [
    ("Farmers Insurance Open", "004"),
    ("Waste Management Phoenix Open", "003"),
    ("AT&T Pebble Beach Pro-Am", "005"),
    ("Genesis Open", "007"),
    ("WGC - Mexico Championship", None),
    ("The Honda Classic", None),
    ("Arnold Palmer Invitational presented by Mastercard", None),
    ("THE PLAYERS Championship", None),
    ("Valspar Championship", None),
    ("WGC - Dell Technologies Match Play", None),
    ("Masters Tournament", None),
    ("Houston Open", None),
    ("RBC Heritage", None),
    ("HOLD FOR ZURICH", None),
    ("Wells Fargo Championship", None),
    ("AT&T Byron Nelson", None),
    ("100th PGA Championship", None),
    ("Fort Worth Invitational", None),
    ("the Memorial Tournament presented by Nationwide", None),
    ("RBC Canadian Open", None),
    ("U.S. Open", None),
    ("Travelers Championship", None),
    ("Aberdeen Standard Investments Scottish Open", None),
    ("Dubai Duty Free Irish Open Hosted by the Rory Foundation", None),
    ("John Deere Classic", None),
    ("A Military Tribute at The Greenbrier", None),
    ("147th Open Championship", None),
    ("FedEx St. Jude Classic", None),
    ("WGC - Bridgestone Invitational", None),
    ("Wyndham Championship", None),
    ("The Northern Trust", None),
    ("Dell Technologies Championship", None),
    ("BMW Championship", None),
    ("TOUR Championship", None),
    ("BMW PGA CHAMPIONSHIP", None),
]

# %%
r = requests.get("https://statdata.pgatour.com/r/489/2019/leaderboard-v2.json")

# %%
r.json()
# Out:
# {'debug': {'msg_id': '36102',
#   'combined_scorecards_file_found': True,
#   'setup_file_found': True,
#   'setup_generated': '2018-10-28T06:03:50',
#   'setup_year': '2019',
#   'current_round_in_setup': 4,
#   'last_round_in_setup': 401,
#   'schedule_file_found': True,
#   'schedule_generated': '2018-10-28T05:47:25',
#   'tournament_in_schedule_file_found': True,
#   'tournament_in_schedule_file_name': 'World Golf Championships-HSBC Champions',
#   'format_in_schedule_file_name': 'Stroke'},
#  'last_updated': '2018-10-28T06:04:05',
#  'time_stamp': '20181028060405',
#  'leaderboard': {'tour_code': 'r',
#   'tour_name': 'PGA TOUR',
#   'tournament_id': '489',
#   'tournament_name': 'World Golf Championships-HSBC Champions',
#   'start_date': '2018-10-25',
#   'end_date': '2018-10-28',
#   'tournament_format': 'stroke',
#   'scoring_type': '1',
#   'in_cup': True,
#   'total_rounds': 4,
#   'is_started': True,
#   'is_finished': True,
#   'current_round': 4,
# ...

# %% [markdown]
# # NOTE:
#
# Made the decision to switch to an owgr client instead of the `statdata.pgatour.com` endpoints because they don't have good results for international tournaments.
