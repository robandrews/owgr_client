# %%
import re
import requests
from collections import defaultdict
from html.parser import HTMLParser

BASE_URL = "http://www.owgr.com"

# %%
def is_str_blank(s):
    return all([ch == " " for ch in s])

def clean_html(s):
    return s.strip().replace("\n","").replace("\r", "")

def get_id_from_player_url(player_url):
    r = re.compile("\d+")
    m = re.search(r, player_url)
    return m.group(0)

#         1	2-3	4-10	11-25	Made Cut	Missed Cut / WD / DQ
def get_bucket_from_standing(pos):
    r = re.compile("\d+")
    m = r.search(pos)
    if m is not None:
        place = int(m.group(0))
        if place == 1:
            return "1"
        elif place < 4:
            return "2-3"
        elif place < 11:
            return "4-10"
        elif place < 26:
            return "11-25"
        else:
            return "CM"
    else:
        return "boo"

# %%
print(get_bucket_from_standing("MC"))
print(get_bucket_from_standing("T2"))
print(get_bucket_from_standing("T123"))
print(get_bucket_from_standing("DNP"))
print(get_bucket_from_standing("no idea"))
# Out:
# bad
# 2
# 123
# bad
# bad

# %% [markdown]
# ## Parse Events

# %%
COLS = ["Week", "Year", "Tour", "EventUrl", "EventName", "PlayerUrl", "Winner", "WinnerPoints", "WorldRating", "HomeRating", "SoF"]


class OwgrEventsHtmlParser(HTMLParser):
    def __init__(self):
        self.debug = False
        self.at_table = False
        self.row = None
        self.all_rows = []
        
        super().__init__()
    
    def handle_starttag(self, tag, attrs):
        if not self.at_table and tag == "table":
            self.at_table = True
        
        if self.at_table:
            if tag == "tr":
                if self.debug:
                    print("starting new row")
                self.row = []
            
            if self.row is not None and tag == "a":
                self.row.append(attrs[0][1])

    def handle_endtag(self, tag):
        if self.at_table and tag == "table":
            if self.debug:
                print("Leaving the table :", tag)
            self.at_table = False

        if tag == "tr":
            r = [el.strip() for el in self.row]
            if self.debug:
                print("Leaving the row :", tag)
                print(r)
            d = dict(zip(COLS, r))
            self.all_rows.append(d)
            self.row = None

    def handle_data(self, data):
        if self.at_table and self.row is not None:
            if not is_str_blank(data):
                self.row.append(data)

# %%
r = requests.get("http://www.owgr.com/events")

# %%
t = r.text.strip().replace("\n","").replace("\r", "")

# %%
p = OwgrEventsHtmlParser()

# %%
p.feed(t)

# %%
events = p.all_rows[1:]

# %%
all_2018_events = [el["EventName"] for el in events]
all_2018_events.reverse()
all_2018_events
# Out:
# ['Sentry Tournament of Champions',
#  'Sony Open in Hawaii',
#  'BMW SA Open hosted by the City of Ekurhuleni',
#  'REBEL Sport Masters',
#  'CareerBuilder Challenge',
#  'The Bahamas Great Exuma Classic at Sandals Emerald Bay',
#  'Red Sea Egyptian Classic',
#  'SMBC Singapore Open',
#  'Abu Dhabi HSBC Championship presented by EGA',
#  'Farmers Insurance Open',
#  'Leopalace21 Myanmar Open',
#  'Omega Dubai Desert Classic',
#  'The Bahamas Great Abaco Classic at The Abaco Club',
#  'Red Sea Ain Sokhna Classic',
#  'PGM Darulaman Championship',
#  'Maybank Championship',
#  'Oates Vic Open',
#  'Panama Championship',
#  'Waste Management Phoenix Open',
#  'ISPS Handa World Super 6 Perth',
#  'AT&T Pebble Beach Pro-Am',
#  'Open Prestigia',
#  'Eye of Africa PGA Championship',
#  'Club Colombia Championship',
#  'Open Casa Green Golf',
#  'Ein Bay Open',
#  'Genesis Open',
#  'NBO Oman Open',
#  'Coca-Cola QLD PGA Championship',
#  'Dimension Data Pro-Am',
#  'Mediter Real Estate Masters',
#  'The Honda Classic',
#  'Horizon Golf NZ PGA Championship',
#  'Commercial Bank Qatar Masters',
#  'Cape Town Open presented by Sun International',
#  'PGA Catalunya Resort Championship',
#  'Red Sea Little Venice Open',
#  'Lumine Lakes Open',
#  'ISPS HANDA New Zealand Open',
#  'Tshwane Open',
#  'WGC - Mexico Championship',
#  'Lumine Hills Open',
#  'Open Madaef',
#  'Richard Mille Brunei Championships',
#  'El Bosque Mexico Championship by Innova',
#  'Valspar Championship',
#  'Shenzhou Peninsula Classic',
#  'Hero Indian Open',
#  'Guatemala Stella Artois Open',
#  'Chengdu Championship',
#  'The Tour Championship',
#  'Arnold Palmer Invitational presented by Mastercard',
#  'OB Golf Invitational',
#  'Chongqing Championship',
#  'Chitimacha Louisiana Open presented by NACHER',
#  'Corales Puntacana Resort & Club Championship',
#  'Barclays Kenya Open',
#  'WGC - Dell Technologies Match Play',
#  '59 Abierto Mexicano de Golf',
#  'Bo Ao Open',
#  'Savannah Golf Championship',
#  'Houston Open',
#  'Open Ocean',
#  'Open Tazegzout',
#  'Masters Tournament',
#  'PGM Johor Championship',
#  'Open Royal Golf Anfa Mohammedia',
#  'Token Homemate Cup',
#  'RBC Heritage',
#  'Obidos International Open',
#  'Zanaco Masters',
#  'Open de Espana',
#  '87 Abierto OSDE del Centro presentado por FiberCorp',
#  'Belt & Road Colorful Yunnan Open',
#  'The 14th Dongbu Insurance Promy Open',
#  'Molino Cañuelas Championship',
#  'Big Easy Challenge 1 - Silver Lakes',
#  'Zimbabwe Open',
#  'Trophee Hassan II',
#  'Colorful Yunnan Classic',
#  'Valero Texas Open',
#  'North Mississippi Classic',
#  'Panasonic Open Championship',
#  'The Crowns',
#  'United Leasing & Finance Championship',
#  'Turkish Airlines Challenge',
#  'Haugschlag NÖ Open',
#  'BTI Open',
#  'Volvo China Open',
#  'Bravo Tours Open - by Visit Tønder',
#  'Mopani Redpath Zambia Open 2018',
#  'SP PNG Golf Open',
#  'Challenge de España',
#  'Changsha Championship',
#  'PGM Penang Championship',
#  'Willis Towers Watson Masters, by Egekilde',
#  'BMW Jamaica Classic',
#  'Wells Fargo Championship',
#  'The 37th GS Caltex Maekyung Open Golf Championship',
#  'Japan PGA Championship',
#  'TX Civil & Logistics WA PGA Championship',
#  'Investec Royal Swazi Open',
#  'THE PLAYERS Championship',
#  'Costa Rica Classic',
#  'Haikou Championship',
#  'Knoxville Open',
#  '56º Open de Portugal @ Morgado Golf Resort',
#  'Rocco Forte Sicilian Open',
#  'Singha Laguna Phuket Open',
#  'AB Bank Bangladesh Open',
#  'EXTEC Trophy 2018 by ATOMIC DRINKS',
#  'Master of the Monster',
#  'Stora Hotellet Bryggan Fjällbacka Open',
#  'Puerto Plata DR Open',
#  'Asia-Pacific Classic',
#  'Big Easy Challenge 2 - Modderfontein',
#  'The Motocaddy Masters',
#  'Andalucia - Costa de Sol Match Play 9',
#  'AT&T Byron Nelson',
#  'SK Telecom Open',
#  'Belgian Knockout',
#  'Kansai Open Golf Championship',
#  'BMW Charity Pro-Am presented by SYNNEX Corporation',
#  'Lombard Insurance Classic',
#  'BMW PGA CHAMPIONSHIP',
#  'Fort Worth Invitational',
#  'Genesis Championship',
#  'Betagro Championship',
#  'Gate Way To The Open Mizuno Open at The Royal GC',
#  'Pärnu Bay Golf Links Challenge',
#  'Big Easy Challenge 3 - State Mines',
#  'Nashville Golf Open Benefitting the Snedeker Foundation',
#  'D+D REAL Czech Challenge',
#  'Gosser Open',
#  'Open de Saint Francois Region Guadeloupe',
#  'The Matchroom Sport Championship',
#  'Rex Hospital Open',
#  'the Memorial Tournament presented by Nationwide',
#  'Freedom 55 Financial Open',
#  'Quito Open presentado por Diners Club',
#  'Jyske Bank PGA Championship',
#  'Italian Open',
#  'KB Finance LIIV Championship',
#  'Raiffeisen Pro Golf Tour St. Pölten 2018 presented by Elation Travel',
#  'JGT Championship Mori Building Cup Shishido Hills',
#  'Swiss Challenge presented by Association Suisse de Golf',
#  'Sun City Challenge',
#  'Descente Korea Munsingwear Matchplay',
#  'FedEx St. Jude Classic',
#  'KPMG Trophy',
#  'Shot Clock Masters',
#  'Thailand Open',
#  'Bupa Match Play',
#  'Rust-Oleum Championship',
#  'The PDC Golf Championship',
#  'PGA Championship hosted by Ingelsta Kalkon',
#  'Bayview Place DCBank Open presented by Times Colonist',
#  'Guilin Championship',
#  'Big Easy Challenge 4 - Randpark',
#  'GolfBC Championship',
#  'Kunming Championship',
#  'Alps de Andalucia',
#  'U.S. Open',
#  'The 12 Twelve Championship - by Thisted Forsikring',
#  'KEB Hana Bank Invitational',
#  'Eagle Orchid Scottish Masters',
#  'Hauts de France Golf Open',
#  'Travelers Championship',
#  "Wichita Open Supporting Wichita's Youth",
#  'Dunlop SRIXON Fukushima Open',
#  'SSE Scottish Hydro Challenge hosted by Macdonald Hotels & Resorts',
#  'Kolon Korea Open Golf Championship',
#  'Lethbridge Paradise Canyon Open',
#  'BMW International Open',
#  "Open International de La Mirabelle D'or",
#  'McNeill Open 2018 sponsored by KUHN Maßkonfektion',
#  'Jessie May World Snooker Championship',
#  'Gamle Fredrikstad Open',
#  'Big Easy Challenge - Killarney',
#  'The Cumberwell Park Championship',
#  'Lincoln Land Championship presented by LRS',
#  'Open la Pinetina - Memorial Giorgio Bordoni',
#  'The 61st KPGA Championship with A-ONE CC',
#  'SM Match',
#  "Queen's Cup presented by Bangchak",
#  'Made in Denmark Challenge presented by Ejner Hessel',
#  'Polish Open',
#  'HNA Open de France',
#  'Quicken Loans National',
#  'Shigeo Nagashima Invitational SEGA SAMMY Cup',
#  'A Military Tribute at The Greenbrier',
#  'Dubai Duty Free Irish Open Hosted by the Rory Foundation',
#  'Prague Golf Challenge',
#  'LECOM Health Challenge',
#  'Sarawak Championship',
#  'Windsor Championship',
#  'The Dawson and Sanderson Classic',
#  'Broekpolder International Open',
#  'Camfil Nordic Championship',
#  'Big Easy Challenge 6 - Centurion',
#  'St Malo Golf Open',
#  'NS HomeShopping Gunsan CC Jeonbuk Open',
#  'Staal Foundation Open presented by tbaytel',
#  'Utah Championship presented by Zions Bank',
#  'The Clipper Logistics Championship',
#  'Yantai Championship',
#  'Gut Bissenmoor Classic 2018',
#  'Italian Challenge presented by Cashback World',
#  'John Deere Classic',
#  'Aberdeen Standard Investments Scottish Open',
#  'Fred Olsen Alps del la Gomera',
#  'Bank BRI Indonesia Open',
#  'Pinnacle Bank Championship presented by Heartland Chevy Dealers',
#  'The Ablrate.com Championship',
#  '147th Open Championship',
#  'Le Vaudreuil Golf Challenge',
#  'Barbasol Championship',
#  'Zell am See- Kaprun Open 2018 presented by SalzburgerLand',
#  'Alps de las Castillas',
#  'Qingdao Championship',
#  'Osprey Valley Open',
#  'KCB Karen Masters',
#  'Des Iles Borromees Open Presented by Cashback',
#  'The Pentahotels Championship',
#  'PGM Northport Championship',
#  'Price Cutter Charity Championship presented by Dr Pepper',
#  'Euram Bank Open',
#  'Beijing Championship',
#  'Porsche European Open',
#  'Royal Cup',
#  'RBC Canadian Open',
#  'IFX and Winged Boots Championship',
#  'Fiji International presented by Fiji Airways',
#  'Swedish Challenge hosted by Robert Karlsson',
#  'Louis Philippe Cup',
#  'WGC - Bridgestone Invitational',
#  'Barracuda Championship',
#  'Syncrude Oil Country Championship presented by AECON',
#  'KC Golf Classic',
#  'Sun Royal Spa Swazi Challenge',
#  'Made in Denmark - by EnergiMetropol Esbjerg',
#  'ATB Financial Classic',
#  'Vierumäki Finnish Challenge',
#  'OnePartnerGroup Open',
#  'Ellie Mae Classic at TPC Stonebrae',
#  'TAKE Solutions Masters',
#  'Sun Carnival City Challenge',
#  'Big Easy Challenge 7 -Bushwillow- Randpark',
#  'Leipziger Golf Open',
#  '100th PGA Championship',
#  'Nokia Masters',
#  'PGM Sabah Championship',
#  'The FORE Business Championship',
#  'DONG-A Membership Exchange Group Busan Open',
#  'Taifong Open',
#  'Wyndham Championship',
#  'MMC Northern Territory PGA Championship',
#  'Nordea Masters',
#  'Starnberg Open',
#  'Holtsmark Open',
#  'Galgorm Resort & Spa Northern Ireland Open, presented by Modest! Golf',
#  'Vodacom Origins of Golf - Zebula',
#  'WinCo Foods Portland Open presented by Kraft-Heinz',
#  'Players Cup',
#  'PGM Labuan Championship',
#  'The Northern Trust',
#  'Big Easy Challenge 8 - Wingate Park',
#  'Åhus KGK ProAm',
#  'Rolex Trophy',
#  "Nationwide Children's Hospital Championship",
#  'RIZAP KBC Augusta',
#  'D+D Real Czech Masters',
#  'Sun Wild Coast Sun Challenge',
#  'Ciputra Golfpreneur Tournament presented by Panasonic',
#  'Vodacom Origins of Golf - Selborne',
#  'Timberwise Finnish Open hosted by Jaakko Mäkitalo',
#  'Suzhou Championship',
#  'Cervino Open',
#  'The Prem Group Irish Masters',
#  'Made In Denmark',
#  'DAP Championship presented by NewBrick',
#  'Fujisankei Classic',
#  'Dell Technologies Championship',
#  'DGB Financial Group Daegu Gyeongbuk Open',
#  'Cordon Golf Open',
#  'Omega European Masters',
#  'Bråviken Open',
#  'Mackenzie Investments Open presented by Jaguar Laval',
#  'Qinhuangdao Championship',
#  'Big Easy Challenge 9 - Kyalami',
#  'PGM MIRI Championship',
#  'Bridgestone Challenge',
#  'NEW GOLF CLUB Matchplay Championship',
#  'BMW Championship',
#  'ISPS Handa Match Play',
#  'The 34th Shinhan Donghae Open',
#  'Albertsons Boise Open presented by Kraft Nabisco',
#  'Vodacom Origins of Golf - Arabella',
#  'KLM Open',
#  'PGM MNRB Championship',
#  'Freedom 55 Financial Championship',
#  'Kazakhstan Open',
#  'Sao Paulo Golf Club Championship',
#  'Tinderbox Charity Challenge - by The Agger Foundation',
#  'Web.com Tour Championship',
#  'Open Abruzzo',
#  'Newmachar Golf Club Challenge',
#  'Hopps Open de Provence',
#  '65 JHSF Brazil Open',
#  'Big Easy Challenge 10 - Services',
#  'Portugal Masters',
#  'Huons Celebrity Pro-Am',
#  'Harboe Open - by Slagelse Kommune & Sparekassen Kronjylland',
#  'TOUR Championship',
#  'Asia-Pacific Diamond Cup Golf',
#  'Top Cup Tokai Classic',
#  'Mercuries Taiwan Masters',
#  'Vodacom Origins of Golf - St Francis Links',
#  'Castanea Resort Championship',
#  'Ekerum Öland Masters',
#  'Macau Championship',
#  'San Luis Championship',
#  'Zhuhai Championship',
#  'Race to Himmerland',
#  'PGM UMW Championship',
#  'Yeangder TPC',
#  'Safeway Open',
#  'Alfred Dunhill Links Championship',
#  'Monaghan Irish Challenge',
#  'Victorian PGA Championship',
#  'PGM CCM Championship',
#  'CIMB Classic',
#  'Tourfinalen hosted by Barsebäck Resort',
#  'Hainan Open',
#  'Sky Sports British Masters',
#  'Japan Open Golf Championship',
#  'UMA CNS Open Golf Championship',
#  'Volvo Abierto de Chile 2018',
#  'Big Easy Challenge 11 - Reading',
#  'Clearwater Bay Open',
#  'PGM MIDF Championship',
#  'Foshan Open',
#  'The CJ Cup @ Nine Bridges',
#  'Diners Club Peru Open presentado por Lexus',
#  'Bridgestone Open',
#  'Alps Tour Grand Final',
#  'Vodacom Origins of Golf Parys',
#  'Andalucia Valderrama Masters hosted by the Sergio Garcia Foundation',
#  'Mynavi ABC Championship',
#  'Sibaya Challenge',
#  'Hyundai Insurance KJ Choi Invitational',
#  'Panasonic Open India',
#  'Tour Championship',
#  'Nexus Risk TSA Group WA Open',
#  'WGC - HSBC Champions',
#  'Sanderson Farms Championship',
#  'Big Easy Challenge 12 - Benoni',
#  'Ras Al Khaimah Challenge Tour Grand Final',
#  'Big Easy Challenge 13 - Eagle Canyon',
#  'Shriners Hospitals for Children Open',
#  'Isuzu Queensland Open',
#  'Turkish Airlines Open',
#  'HEIWA PGM CHAMPIONSHIP',
#  'A+ Life Hyodam Jeju Open with MTN',
#  'Vodacom Origins of Golf Final',
#  'Mitsui Sumitomo VISA Taiheiyo Masters',
#  'Neuquen Argentina Classic',
#  'Nedbank Golf Challenge Hosted by Gary Player',
#  'Mayakoba Golf Classic',
#  'Golfzon · DYB Education Tour Championship',
#  'AVJennings NSW Open',
#  'Combiphar Players Championship',
#  'Big Easy Challenge 14 - Irene',
#  '113 VISA Open de Argentina presentado por Macro',
#  'Emirates Australian Open',
#  'DP World Tour Championship, Dubai',
#  'The RSM Classic',
#  'Dunlop Phoenix Tournament',
#  'Casio World Open',
#  'Chongqing Kingrun Open',
#  'Honma Hong Kong Open presented by Amundi',
#  'Hero World Challenge',
#  'Big Easy Challenge 15 - Parkview',
#  'Afrasia Bank Mauritius Open at Anahita',
#  'Golf Nippon Series JT Cup  2018',
#  'Shell Championship',
#  "Queen's Cup hosted by Jaidee Foundation",
#  'PGM Maybank Championship',
#  'Australian PGA Championship',
#  'South African Open',
#  'Xiamen Open',
#  'Big Easy Tour Championship',
#  'The China Great Bay Open',
#  'Alfred Dunhill Championship',
#  'BNI Indonesian Masters']

# %% [markdown]
# ## Parse single event

# %%
e = events[0]["EventUrl"]
r = requests.get(BASE_URL + e)

# %%
h = clean_html(r.text)

# %%
EVENT_COLS = ['Pos', 'PlayerUrl', 'Name', 'R1', 'R2', 'R3', 'R4', 'Agg', 'Ranking Points']


class OwgrSingleEventHtmlParser(HTMLParser):
    def __init__(self):
        self.at_table = False
        self.row = None
        self.all_rows = []
        self.debug = False
        
        super().__init__()
    
    def handle_starttag(self, tag, attrs):
        if not self.at_table and tag == "table":
            if self.debug:
                print("Starting table")
            self.at_table = True
        
        if self.at_table:
            if tag == "tr":
                if self.debug:
                    print("starting new row")
                self.row = []
            
            if self.row is not None and tag == "a":
                self.row.append(attrs[0][1])

    def handle_endtag(self, tag):
        if self.at_table and tag == "table":
            if self.debug:
                print("Leaving the table :", tag)
            self.at_table = False

        if tag == "tr":
            r = [el.strip() for el in self.row]
            if self.debug:
                print(r)
                print("Leaving the row :", tag)
            if len(r) > 0:
                d = dict(zip(EVENT_COLS, self.row))
                self.all_rows.append(d)
            self.row = None

    def handle_data(self, data):
        if self.at_table and self.row is not None:
            if not is_str_blank(data):
                self.row.append(data)

# %%
p = OwgrSingleEventHtmlParser()
p.feed(h)

# %%
p.all_rows[1:]
# Out:
# [{'Pos': '1',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14951',
#   'Name': 'Poom Saksansin',
#   'R1': '67',
#   'R2': '63',
#   'R3': '70',
#   'R4': '68',
#   'Agg': '268',
#   'Ranking Points': '24'},
#  {'Pos': '2',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14368',
#   'Name': 'Jazz Janewattananond',
#   'R1': '68',
#   'R2': '69',
#   'R3': '69',
#   'R4': '65',
#   'Agg': '271',
#   'Ranking Points': '14.4'},
#  {'Pos': '3',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14133',
#   'Name': 'Panuphol Pittayarat',
#   'R1': '71',
#   'R2': '66',
#   'R3': '70',
#   'R4': '66',
#   'Agg': '273',
#   'Ranking Points': '9.6'},
#  {'Pos': '4',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=5994',
#   'Name': 'Henrik Stenson',
#   'R1': '67',
#   'R2': '68',
#   'R3': '68',
#   'R4': '71',
#   'Agg': '274',
#   'Ranking Points': '7.2'},
#  {'Pos': '5',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14129',
#   'Name': 'Thitiphun Chuayprakong',
#   'R1': '67',
#   'R2': '70',
#   'R3': '74',
#   'R4': '64',
#   'Agg': '275',
#   'Ranking Points': '5.76'},
#  {'Pos': '6',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=9553',
#   'Name': 'Shiv Kapur',
#   'R1': '71',
#   'R2': '66',
#   'R3': '71',
#   'R4': '69',
#   'Agg': '277',
#   'Ranking Points': '4.8'},
#  {'Pos': 'T7',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13307',
#   'Name': 'Sihwan Kim',
#   'R1': '69',
#   'R2': '69',
#   'R3': '70',
#   'R4': '71',
#   'Agg': '279',
#   'Ranking Points': '4.08'},
#  {'Pos': 'T7',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=16266',
#   'Name': 'Jakraphan Premsirigorn',
#   'R1': '68',
#   'R2': '65',
#   'R3': '74',
#   'R4': '72',
#   'Agg': '279',
#   'Ranking Points': '4.08'},
#  {'Pos': 'T9',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18150',
#   'Name': 'Suradit Yongcharoenchai',
#   'R1': '67',
#   'R2': '66',
#   'R3': '75',
#   'R4': '72',
#   'Agg': '280',
#   'Ranking Points': '3.36'},
#  {'Pos': 'T9',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=20882',
#   'Name': 'Viraj Madappa',
#   'R1': '73',
#   'R2': '69',
#   'R3': '72',
#   'R4': '66',
#   'Agg': '280',
#   'Ranking Points': '3.36'},
#  {'Pos': 'T9',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12889',
#   'Name': 'Nicholas Fung',
#   'R1': '69',
#   'R2': '71',
#   'R3': '78',
#   'R4': '62',
#   'Agg': '280',
#   'Ranking Points': '3.36'},
#  {'Pos': 'T12',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13485',
#   'Name': 'Shugo Imahira',
#   'R1': '71',
#   'R2': '70',
#   'R3': '73',
#   'R4': '67',
#   'Agg': '281',
#   'Ranking Points': '2.472'},
#  {'Pos': 'T12',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13924',
#   'Name': 'Sungho Lee',
#   'R1': '66',
#   'R2': '71',
#   'R3': '74',
#   'R4': '70',
#   'Agg': '281',
#   'Ranking Points': '2.472'},
#  {'Pos': 'T12',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=9985',
#   'Name': 'Chapchai Nirat',
#   'R1': '69',
#   'R2': '67',
#   'R3': '76',
#   'R4': '69',
#   'Agg': '281',
#   'Ranking Points': '2.472'},
#  {'Pos': 'T12',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=6433',
#   'Name': 'Lin Wen-Tang',
#   'R1': '69',
#   'R2': '70',
#   'R3': '72',
#   'R4': '70',
#   'Agg': '281',
#   'Ranking Points': '2.472'},
#  {'Pos': 'T12',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14821',
#   'Name': 'Jarin Todd',
#   'R1': '68',
#   'R2': '70',
#   'R3': '72',
#   'R4': '71',
#   'Agg': '281',
#   'Ranking Points': '2.472'},
#  {'Pos': 'T17',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18524',
#   'Name': 'John Catlin',
#   'R1': '66',
#   'R2': '72',
#   'R3': '75',
#   'R4': '69',
#   'Agg': '282',
#   'Ranking Points': '1.92'},
#  {'Pos': 'T17',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=6093',
#   'Name': 'Justin Rose',
#   'R1': '68',
#   'R2': '68',
#   'R3': '71',
#   'R4': '75',
#   'Agg': '282',
#   'Ranking Points': '1.92'},
#  {'Pos': 'T17',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=7481',
#   'Name': 'Steven Jeffress',
#   'R1': '69',
#   'R2': '71',
#   'R3': '73',
#   'R4': '69',
#   'Agg': '282',
#   'Ranking Points': '1.92'},
#  {'Pos': 'T20',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=7040',
#   'Name': 'S.S.P. Chawrasia',
#   'R1': '71',
#   'R2': '70',
#   'R3': '74',
#   'R4': '68',
#   'Agg': '283',
#   'Ranking Points': '1.52'},
#  {'Pos': 'T20',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12669',
#   'Name': 'Anirban Lahiri',
#   'R1': '68',
#   'R2': '72',
#   'R3': '71',
#   'R4': '72',
#   'Agg': '283',
#   'Ranking Points': '1.52'},
#  {'Pos': 'T20',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13885',
#   'Name': 'Carlos Pigem',
#   'R1': '71',
#   'R2': '68',
#   'R3': '74',
#   'R4': '70',
#   'Agg': '283',
#   'Ranking Points': '1.52'},
#  {'Pos': 'T20',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=16835',
#   'Name': 'Jarryd Felton',
#   'R1': '67',
#   'R2': '76',
#   'R3': '69',
#   'R4': '71',
#   'Agg': '283',
#   'Ranking Points': '1.52'},
#  {'Pos': 'T24',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=11978',
#   'Name': "Jbe' Kruger",
#   'R1': '73',
#   'R2': '69',
#   'R3': '72',
#   'R4': '70',
#   'Agg': '284',
#   'Ranking Points': '1.27'},
#  {'Pos': 'T24',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=2035',
#   'Name': 'Daniel Chopra',
#   'R1': '73',
#   'R2': '68',
#   'R3': '74',
#   'R4': '69',
#   'Agg': '284',
#   'Ranking Points': '1.27'},
#  {'Pos': 'T24',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=7038',
#   'Name': 'Rahil Gangjee',
#   'R1': '72',
#   'R2': '71',
#   'R3': '71',
#   'R4': '70',
#   'Agg': '284',
#   'Ranking Points': '1.27'},
#  {'Pos': 'T24',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=10316',
#   'Name': 'Berry Henson',
#   'R1': '68',
#   'R2': '74',
#   'R3': '73',
#   'R4': '69',
#   'Agg': '284',
#   'Ranking Points': '1.27'},
#  {'Pos': 'T28',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=6165',
#   'Name': 'Keith Horne',
#   'R1': '72',
#   'R2': '70',
#   'R3': '74',
#   'R4': '69',
#   'Agg': '285',
#   'Ranking Points': '0'},
#  {'Pos': 'T28',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=7070',
#   'Name': 'Marcus Fraser',
#   'R1': '73',
#   'R2': '68',
#   'R3': '73',
#   'R4': '71',
#   'Agg': '285',
#   'Ranking Points': '0'},
#  {'Pos': 'T28',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12838',
#   'Name': 'Steve Lewton',
#   'R1': '72',
#   'R2': '71',
#   'R3': '72',
#   'R4': '70',
#   'Agg': '285',
#   'Ranking Points': '0'},
#  {'Pos': 'T28',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15849',
#   'Name': 'Jake Higginbottom',
#   'R1': '69',
#   'R2': '69',
#   'R3': '79',
#   'R4': '68',
#   'Agg': '285',
#   'Ranking Points': '0'},
#  {'Pos': 'T32',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=8612',
#   'Name': 'Ben Leong',
#   'R1': '69',
#   'R2': '71',
#   'R3': '75',
#   'R4': '71',
#   'Agg': '286',
#   'Ranking Points': '0'},
#  {'Pos': 'T32',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=11958',
#   'Name': 'Pavit Tangkamolprasert',
#   'R1': '68',
#   'R2': '70',
#   'R3': '77',
#   'R4': '71',
#   'Agg': '286',
#   'Ranking Points': '0'},
#  {'Pos': 'T32',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=6386',
#   'Name': 'Danny Chia',
#   'R1': '68',
#   'R2': '73',
#   'R3': '76',
#   'R4': '69',
#   'Agg': '286',
#   'Ranking Points': '0'},
#  {'Pos': 'T35',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=1888',
#   'Name': 'Scott Hend',
#   'R1': '68',
#   'R2': '73',
#   'R3': '73',
#   'R4': '73',
#   'Agg': '287',
#   'Ranking Points': '0'},
#  {'Pos': 'T35',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=7438',
#   'Name': 'Angelo Que',
#   'R1': '67',
#   'R2': '74',
#   'R3': '73',
#   'R4': '73',
#   'Agg': '287',
#   'Ranking Points': '0'},
#  {'Pos': 'T35',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13786',
#   'Name': 'Pannakorn Uthaipas',
#   'R1': '69',
#   'R2': '74',
#   'R3': '75',
#   'R4': '69',
#   'Agg': '287',
#   'Ranking Points': '0'},
#  {'Pos': 'T35',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=11828',
#   'Name': 'Josh Younger',
#   'R1': '66',
#   'R2': '70',
#   'R3': '78',
#   'R4': '73',
#   'Agg': '287',
#   'Ranking Points': '0'},
#  {'Pos': 'T35',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15156',
#   'Name': 'Khalin Joshi',
#   'R1': '68',
#   'R2': '76',
#   'R3': '75',
#   'R4': '68',
#   'Agg': '287',
#   'Ranking Points': '0'},
#  {'Pos': 'T35',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18577',
#   'Name': 'Micah Lauren Shin',
#   'R1': '73',
#   'R2': '70',
#   'R3': '74',
#   'R4': '70',
#   'Agg': '287',
#   'Ranking Points': '0'},
#  {'Pos': 'T41',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18236',
#   'Name': 'Settee Prakongvech',
#   'R1': '69',
#   'R2': '74',
#   'R3': '75',
#   'R4': '70',
#   'Agg': '288',
#   'Ranking Points': '0'},
#  {'Pos': 'T41',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=16156',
#   'Name': 'Liu Yanwei',
#   'R1': '73',
#   'R2': '70',
#   'R3': '71',
#   'R4': '74',
#   'Agg': '288',
#   'Ranking Points': '0'},
#  {'Pos': 'T41',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=10086',
#   'Name': 'Sanghyun Park',
#   'R1': '71',
#   'R2': '73',
#   'R3': '74',
#   'R4': '70',
#   'Agg': '288',
#   'Ranking Points': '0'},
#  {'Pos': 'T41',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=7109',
#   'Name': 'Prom Meesawat',
#   'R1': '70',
#   'R2': '73',
#   'R3': '75',
#   'R4': '70',
#   'Agg': '288',
#   'Ranking Points': '0'},
#  {'Pos': 'T45',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13984',
#   'Name': 'Niall Turner',
#   'R1': '71',
#   'R2': '73',
#   'R3': '73',
#   'R4': '72',
#   'Agg': '289',
#   'Ranking Points': '0'},
#  {'Pos': 'T45',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13087',
#   'Name': 'Yutaka Araki',
#   'R1': '72',
#   'R2': '72',
#   'R3': '72',
#   'R4': '73',
#   'Agg': '289',
#   'Ranking Points': '0'},
#  {'Pos': 'T45',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=21415',
#   'Name': 'Varanyu Rattanaphiboonkij',
#   'R1': '73',
#   'R2': '71',
#   'R3': '77',
#   'R4': '68',
#   'Agg': '289',
#   'Ranking Points': '0'},
#  {'Pos': 'T45',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15817',
#   'Name': 'Chikkarangappa S',
#   'R1': '71',
#   'R2': '73',
#   'R3': '76',
#   'R4': '69',
#   'Agg': '289',
#   'Ranking Points': '0'},
#  {'Pos': 'T49',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15513',
#   'Name': 'Lionel Weber',
#   'R1': '73',
#   'R2': '70',
#   'R3': '71',
#   'R4': '76',
#   'Agg': '290',
#   'Ranking Points': '0'},
#  {'Pos': 'T49',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=22815',
#   'Name': 'Maverick Antcliff',
#   'R1': '67',
#   'R2': '75',
#   'R3': '75',
#   'R4': '73',
#   'Agg': '290',
#   'Ranking Points': '0'},
#  {'Pos': 'T49',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18371',
#   'Name': 'Tirawat Kaewsiribandit',
#   'R1': '70',
#   'R2': '74',
#   'R3': '74',
#   'R4': '72',
#   'Agg': '290',
#   'Ranking Points': '0'},
#  {'Pos': 'T49',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=17386',
#   'Name': 'Doyeob Mun',
#   'R1': '71',
#   'R2': '73',
#   'R3': '75',
#   'R4': '71',
#   'Agg': '290',
#   'Ranking Points': '0'},
#  {'Pos': 'T49',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13766',
#   'Name': 'Siddikur Rahman',
#   'R1': '70',
#   'R2': '74',
#   'R3': '75',
#   'R4': '71',
#   'Agg': '290',
#   'Ranking Points': '0'},
#  {'Pos': 'T49',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12881',
#   'Name': 'M. Dharma',
#   'R1': '69',
#   'R2': '75',
#   'R3': '75',
#   'R4': '71',
#   'Agg': '290',
#   'Ranking Points': '0'},
#  {'Pos': 'T55',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=2006',
#   'Name': 'Thammanoon Sriroj',
#   'R1': '70',
#   'R2': '71',
#   'R3': '78',
#   'R4': '72',
#   'Agg': '291',
#   'Ranking Points': '0'},
#  {'Pos': 'T55',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=8170',
#   'Name': 'Lu Wei-chih',
#   'R1': '70',
#   'R2': '70',
#   'R3': '79',
#   'R4': '72',
#   'Agg': '291',
#   'Ranking Points': '0'},
#  {'Pos': 'T57',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=10554',
#   'Name': 'Dengshan Koh',
#   'R1': '71',
#   'R2': '71',
#   'R3': '74',
#   'R4': '76',
#   'Agg': '292',
#   'Ranking Points': '0'},
#  {'Pos': 'T57',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=9774',
#   'Name': 'Andrew Martin',
#   'R1': '72',
#   'R2': '71',
#   'R3': '73',
#   'R4': '76',
#   'Agg': '292',
#   'Ranking Points': '0'},
#  {'Pos': 'T57',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=16424',
#   'Name': 'Danthai Boonma',
#   'R1': '73',
#   'R2': '70',
#   'R3': '77',
#   'R4': '72',
#   'Agg': '292',
#   'Ranking Points': '0'},
#  {'Pos': 'T57',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14953',
#   'Name': 'Rattanon Wannasrichan',
#   'R1': '67',
#   'R2': '72',
#   'R3': '82',
#   'R4': '71',
#   'Agg': '292',
#   'Ranking Points': '0'},
#  {'Pos': '61',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18624',
#   'Name': 'Xiao Bowen',
#   'R1': '70',
#   'R2': '74',
#   'R3': '77',
#   'R4': '73',
#   'Agg': '294',
#   'Ranking Points': '0'},
#  {'Pos': 'T62',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=19381',
#   'Name': 'Amir Nazrin',
#   'R1': '72',
#   'R2': '71',
#   'R3': '79',
#   'R4': '73',
#   'Agg': '295',
#   'Ranking Points': '0'},
#  {'Pos': 'T62',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=19399',
#   'Name': 'Nitithorn Thippong',
#   'R1': '71',
#   'R2': '72',
#   'R3': '76',
#   'R4': '76',
#   'Agg': '295',
#   'Ranking Points': '0'},
#  {'Pos': 'T64',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15307',
#   'Name': 'Danny Masrin',
#   'R1': '71',
#   'R2': '73',
#   'R3': '75',
#   'R4': '79',
#   'Agg': '298',
#   'Ranking Points': '0'},
#  {'Pos': 'T64',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15398',
#   'Name': 'Junhak Lee',
#   'R1': '71',
#   'R2': '73',
#   'R3': '77',
#   'R4': '77',
#   'Agg': '298',
#   'Ranking Points': '0'},
#  {'Pos': '66',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15143',
#   'Name': 'Shinichi Mizuno',
#   'R1': '70',
#   'R2': '72',
#   'R3': '79',
#   'R4': '81',
#   'Agg': '302',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15274',
#   'Name': 'Miguel Tabuena',
#   'R1': '71',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14614',
#   'Name': 'Soomin Lee',
#   'R1': '72',
#   'R2': '73',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14768',
#   'Name': 'Adiyandono Rinaldi',
#   'R1': '68',
#   'R2': '77',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15975',
#   'Name': 'Samuel Cyr',
#   'R1': '71',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=19418',
#   'Name': 'Aman Raj',
#   'R1': '73',
#   'R2': '72',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18214',
#   'Name': 'Paul Harris',
#   'R1': '72',
#   'R2': '73',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12993',
#   'Name': 'Giwhan Kim',
#   'R1': '72',
#   'R2': '73',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=10886',
#   'Name': 'Justin Harding',
#   'R1': '73',
#   'R2': '72',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=11738',
#   'Name': 'Hung Chien-Yao',
#   'R1': '74',
#   'R2': '71',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=8531',
#   'Name': 'Natipong Srithong',
#   'R1': '68',
#   'R2': '77',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=8570',
#   'Name': 'Miguel Angel Carballo',
#   'R1': '71',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=5701',
#   'Name': 'Arjun Atwal',
#   'R1': '71',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '145',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14933',
#   'Name': 'Chanachok Dejpiratanamongkol',
#   'R1': '73',
#   'R2': '73',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '146',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14370',
#   'Name': 'Mitchell Slorach',
#   'R1': '70',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '146',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14373',
#   'Name': 'Ben Campbell',
#   'R1': '73',
#   'R2': '73',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '146',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15528',
#   'Name': 'Heungchol Joo',
#   'R1': '72',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '146',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=21228',
#   'Name': "John O'Toole",
#   'R1': '69',
#   'R2': '77',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '146',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=8364',
#   'Name': 'Andrew Dodt',
#   'R1': '72',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '146',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=3831',
#   'Name': 'Jeev Milkha Singh',
#   'R1': '71',
#   'R2': '75',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '146',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15150',
#   'Name': 'Suttijet Kooratanapisan',
#   'R1': '73',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14377',
#   'Name': 'Matt Stieger',
#   'R1': '71',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14447',
#   'Name': 'Wolmer Murillo',
#   'R1': '75',
#   'R2': '72',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15967',
#   'Name': 'Arnond Vongvanij',
#   'R1': '75',
#   'R2': '72',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=17110',
#   'Name': 'Malcolm Kokocinski',
#   'R1': '74',
#   'R2': '73',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=20657',
#   'Name': 'Fajar Win Nuryanto',
#   'R1': '73',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=19232',
#   'Name': 'Travis Smyth',
#   'R1': '72',
#   'R2': '75',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=16818',
#   'Name': 'Udayan Mane',
#   'R1': '73',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12413',
#   'Name': 'Richard Taehoon Lee',
#   'R1': '71',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13306',
#   'Name': 'Rory Hie',
#   'R1': '70',
#   'R2': '77',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=11089',
#   'Name': 'Naoto Nakanishi',
#   'R1': '75',
#   'R2': '72',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=6397',
#   'Name': 'Gareth Paddison',
#   'R1': '76',
#   'R2': '71',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=7020',
#   'Name': 'Soonsang Hong',
#   'R1': '75',
#   'R2': '72',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '147',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=16076',
#   'Name': 'Kurnia Herisiandy',
#   'R1': '73',
#   'R2': '75',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '148',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=17081',
#   'Name': 'Shubhankar Sharma',
#   'R1': '76',
#   'R2': '72',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '148',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12714',
#   'Name': 'Jamel Ondo',
#   'R1': '71',
#   'R2': '77',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '148',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12332',
#   'Name': 'Namchok Tantipokhakul',
#   'R1': '76',
#   'R2': '72',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '148',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=11823',
#   'Name': 'Daniel Nisbet',
#   'R1': '75',
#   'R2': '73',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '148',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=5898',
#   'Name': 'David Gleeson',
#   'R1': '75',
#   'R2': '73',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '148',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15590',
#   'Name': 'George Gandranata',
#   'R1': '76',
#   'R2': '73',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '149',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=19914',
#   'Name': 'Clement Kurniawan',
#   'R1': '76',
#   'R2': '73',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '149',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=22880',
#   'Name': 'Kentaro Nanayama(Am)',
#   'R1': '74',
#   'R2': '75',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '149',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=17671',
#   'Name': 'Asep Saefulloh',
#   'R1': '68',
#   'R2': '81',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '149',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18221',
#   'Name': "Casey O'Toole",
#   'R1': '70',
#   'R2': '79',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '149',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14072',
#   'Name': 'Indra Hermawan',
#   'R1': '75',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '149',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13801',
#   'Name': 'Ajeetesh Sandhu',
#   'R1': '73',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '149',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=19587',
#   'Name': 'Almay Rayhan(Am)',
#   'R1': '75',
#   'R2': '75',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '150',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18749',
#   'Name': 'Rudi Anto',
#   'R1': '72',
#   'R2': '78',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '150',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18339',
#   'Name': 'Sam Chien',
#   'R1': '75',
#   'R2': '75',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '150',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18202',
#   'Name': 'Jack Harrison',
#   'R1': '74',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '150',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=8739',
#   'Name': 'Tze Huang Choo',
#   'R1': '73',
#   'R2': '77',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '150',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=5876',
#   'Name': 'Young Nam',
#   'R1': '74',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '150',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14758',
#   'Name': 'Elki Kow',
#   'R1': '75',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '151',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12705',
#   'Name': 'Ramadhan Alwie',
#   'R1': '73',
#   'R2': '78',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '151',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=5685',
#   'Name': 'Mardan Mamat',
#   'R1': '72',
#   'R2': '79',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '151',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=14865',
#   'Name': 'Dodge Kemmer',
#   'R1': '74',
#   'R2': '78',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '152',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=17374',
#   'Name': 'Kevin Caesario Akbar(Am)',
#   'R1': '74',
#   'R2': '78',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '152',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18887',
#   'Name': 'Rifqi Alam(Am)',
#   'R1': '72',
#   'R2': '80',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '152',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18369',
#   'Name': 'Naraajie Emerald Ramadhan Putra(Am)',
#   'R1': '78',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '152',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18115',
#   'Name': 'Syukrizal S',
#   'R1': '77',
#   'R2': '75',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '152',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=9698',
#   'Name': 'Chan Shih-chang',
#   'R1': '76',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '152',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=6334',
#   'Name': 'Terry Pilkadaris',
#   'R1': '76',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '152',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=17596',
#   'Name': 'Adrian Halimi',
#   'R1': '77',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '153',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12027',
#   'Name': 'Jubilant Teddy Harmidy(Am)',
#   'R1': '77',
#   'R2': '76',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '153',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=7704',
#   'Name': 'Adam Blyth',
#   'R1': '79',
#   'R2': '74',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '153',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15819',
#   'Name': 'Shohei Hasegawa',
#   'R1': '74',
#   'R2': '80',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '154',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=16013',
#   'Name': 'Honney Baisoya',
#   'R1': '73',
#   'R2': '81',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '154',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=17736',
#   'Name': 'Pasavee Lertvilai',
#   'R1': '73',
#   'R2': '81',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '154',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=12028',
#   'Name': 'Junaidi Ibrahim',
#   'R1': '79',
#   'R2': '75',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '154',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18118',
#   'Name': 'Joshua Andrew Wirawan',
#   'R1': '78',
#   'R2': '77',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '155',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=13420',
#   'Name': 'Hendri Nasim(Am)',
#   'R1': '77',
#   'R2': '79',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '156',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15276',
#   'Name': 'Peter Gunawan',
#   'R1': '82',
#   'R2': '79',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '161',
#   'Ranking Points': '0'},
#  {'Pos': 'WD',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=18149',
#   'Name': 'Phachara Khongwatmai',
#   'R1': '71',
#   'R2': '-',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '71',
#   'Ranking Points': '0'},
#  {'Pos': 'DQ',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=8380',
#   'Name': 'Peradol Panyathanasedh',
#   'R1': '74',
#   'R2': '-',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '74',
#   'Ranking Points': '0'},
#  {'Pos': 'WD',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=6472',
#   'Name': 'Antonio Lascuna',
#   'R1': '74',
#   'R2': '-',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '74',
#   'Ranking Points': '0'},
#  {'Pos': 'WD',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=10995',
#   'Name': 'Benny Kasiadi',
#   'R1': '75',
#   'R2': '-',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '75',
#   'Ranking Points': '0'},
#  {'Pos': 'WD',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=2223',
#   'Name': 'Stephen Lindskog',
#   'R1': '77',
#   'R2': '-',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '77',
#   'Ranking Points': '0'},
#  {'Pos': 'DQ',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=15591',
#   'Name': 'Jordan Irawan',
#   'R1': '78',
#   'R2': '-',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '78',
#   'Ranking Points': '0'},
#  {'Pos': 'MC',
#   'PlayerUrl': '/en/Ranking/PlayerProfile.aspx?playerID=10766',
#   'Name': 'Gaganjeet Bhullar',
#   'R1': '-',
#   'R2': '-',
#   'R3': '-',
#   'R4': '-',
#   'Agg': '0',
#   'Ranking Points': '0'}]

# %% [markdown]
# ## Find events of interest

# %% [markdown]
# ## Get weights

# %%
weights = {}
for l in open("data/2019 draft board for scrape.csv"):
    r = l.strip().split(",")
    try:
        weights[r[1]] = float(r[0])
    except:
        pass

# %%
OUR_TOURNEYS = [k for k,v in weights.items()]

# %%
weights
# Out:
# {'Waste Management Phoenix Open': 1.0,
#  'AT&T Pebble Beach Pro-Am': 1.0,
#  'Genesis Open': 1.0,
#  'WGC - Mexico Championship': 1.5,
#  'The Honda Classic': 1.0,
#  'Arnold Palmer Invitational presented by Mastercard': 1.0,
#  'THE PLAYERS Championship': 1.5,
#  'Valspar Championship': 1.0,
#  'WGC - Dell Technologies Match Play': 1.0,
#  'Masters Tournament': 2.0,
#  'Houston Open': 0.5,
#  'RBC Heritage': 1.0,
#  'HOLD FOR ZURICH': 0.0,
#  'Wells Fargo Championship': 1.0,
#  'AT&T Byron Nelson': 1.0,
#  '100th PGA Championship': 2.0,
#  'Fort Worth Invitational': 1.0,
#  'the Memorial Tournament presented by Nationwide': 1.0,
#  'RBC Canadian Open': 1.0,
#  'U.S. Open': 2.0,
#  'Travelers Championship': 1.0,
#  'Aberdeen Standard Investments Scottish Open': 1.0,
#  'Dubai Duty Free Irish Open Hosted by the Rory Foundation': 1.0,
#  'John Deere Classic': 1.0,
#  'A Military Tribute at The Greenbrier': 0.5,
#  '147th Open Championship': 2.0,
#  'FedEx St. Jude Classic': 1.0,
#  'WGC - Bridgestone Invitational': 1.0,
#  'Wyndham Championship': 1.0,
#  'The Northern Trust': 1.0,
#  'Dell Technologies Championship': 0.5,
#  'BMW Championship': 1.5,
#  'TOUR Championship': 1.5,
#  'BMW PGA CHAMPIONSHIP': 0.5}

# %% [markdown]
# **Check!  All the names of the tournaments are found in our data from OWGR.**

# %%
for el in OUR_TOURNEYS:
    if el not in all_2018_events:
        print(el)
# Out:
# HOLD FOR ZURICH

# %% [markdown]
# ## Parse each event list:

# %%
player_id_to_name = {}
player_id_to_standings = defaultdict(list)

# %%
for event in events:
    if event["EventName"] in OUR_TOURNEYS:
        w = weights[event["EventName"]]
        print(event["EventName"])
        r = requests.get(BASE_URL + event["EventUrl"])
        h = clean_html(r.text)
        p = OwgrSingleEventHtmlParser()
        p.feed(h)
        for el in p.all_rows[1:]:
            i = get_id_from_player_url(el["PlayerUrl"])
            if i not in player_id_to_name:
                player_id_to_name[i] = el["Name"]
            player_id_to_standings[i].append((el["Pos"], w))
# Out:
# TOUR Championship
# BMW Championship
# Dell Technologies Championship
# The Northern Trust
# Wyndham Championship
# 100th PGA Championship
# WGC - Bridgestone Invitational
# RBC Canadian Open
# 147th Open Championship
# Aberdeen Standard Investments Scottish Open
# John Deere Classic
# Dubai Duty Free Irish Open Hosted by the Rory Foundation
# A Military Tribute at The Greenbrier
# Travelers Championship
# U.S. Open
# FedEx St. Jude Classic
# the Memorial Tournament presented by Nationwide
# Fort Worth Invitational
# BMW PGA CHAMPIONSHIP
# AT&T Byron Nelson
# THE PLAYERS Championship
# Wells Fargo Championship
# RBC Heritage
# Masters Tournament
# Houston Open
# WGC - Dell Technologies Match Play
# Arnold Palmer Invitational presented by Mastercard
# Valspar Championship
# WGC - Mexico Championship
# The Honda Classic
# Genesis Open
# AT&T Pebble Beach Pro-Am
# Waste Management Phoenix Open

# %%
{player_id_to_name[k]: v for k,v in  player_id_to_standings.items()}
# Out:
# {'Tiger Woods': [('1', 1.5),
#   ('T6', 1.5),
#   ('T24', 0.5),
#   ('T40', 1.0),
#   ('2', 2.0),
#   ('T31', 1.0),
#   ('T6', 2.0),
#   ('MC', 2.0),
#   ('T23', 1.0),
#   ('T11', 1.5),
#   ('T55', 1.0),
#   ('T32', 2.0),
#   ('T5', 1.0),
#   ('T2', 1.0),
#   ('12', 1.0),
#   ('MC', 1.0)],
#  'Billy Horschel': [('2', 1.5),
#   ('T3', 1.5),
#   ('WD', 0.5),
#   ('T3', 1.0),
#   ('T11', 1.0),
#   ('T35', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T51', 1.0),
#   ('MC', 1.0),
#   ('T21', 1.0),
#   ('T37', 1.5),
#   ('T5', 1.0),
#   ('MC', 2.0),
#   ('T54', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T43', 1.0)],
#  'Dustin Johnson': [('3', 1.5),
#   ('T24', 1.5),
#   ('T7', 0.5),
#   ('T11', 1.0),
#   ('T27', 2.0),
#   ('T3', 1.0),
#   ('1', 1.0),
#   ('MC', 2.0),
#   ('3', 2.0),
#   ('1', 1.0),
#   ('T8', 1.0),
#   ('T17', 1.5),
#   ('T16', 1.0),
#   ('T10', 2.0),
#   ('T59', 1.0),
#   ('T7', 1.5),
#   ('T16', 1.0),
#   ('T2', 1.0)],
#  'Webb Simpson': [('T4', 1.5),
#   ('T6', 1.5),
#   ('T49', 0.5),
#   ('T28', 1.0),
#   ('T2', 1.0),
#   ('T19', 2.0),
#   ('T24', 1.0),
#   ('T12', 2.0),
#   ('T47', 0.5),
#   ('MC', 1.0),
#   ('T10', 2.0),
#   ('MC', 1.0),
#   ('1', 1.5),
#   ('T21', 1.0),
#   ('T5', 1.0),
#   ('T20', 2.0),
#   ('T29', 1.0),
#   ('T8', 1.0),
#   ('T37', 1.5),
#   ('T5', 1.0),
#   ('MC', 1.0)],
#  'Justin Rose': [('T4', 1.5),
#   ('2', 1.5),
#   ('2', 0.5),
#   ('MC', 1.0),
#   ('T19', 2.0),
#   ('T2', 2.0),
#   ('T9', 1.0),
#   ('T10', 2.0),
#   ('T6', 1.0),
#   ('1', 1.0),
#   ('T23', 1.5),
#   ('T12', 2.0),
#   ('T52', 0.5),
#   ('3', 1.0),
#   ('T5', 1.0),
#   ('T37', 1.5)],
#  'Hideki Matsuyama': [('T4', 1.5),
#   ('15', 1.5),
#   ('T4', 0.5),
#   ('T15', 1.0),
#   ('T11', 1.0),
#   ('T35', 2.0),
#   ('T39', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('T16', 2.0),
#   ('T13', 1.0),
#   ('T16', 1.0),
#   ('MC', 1.5),
#   ('T76', 1.0),
#   ('19', 2.0),
#   ('T36', 1.0),
#   ('T49', 1.0),
#   ('WD', 1.0)],
#  'Rickie Fowler': [('T7', 1.5),
#   ('T8', 1.5),
#   ('T12', 2.0),
#   ('T17', 1.0),
#   ('T28', 2.0),
#   ('T6', 1.0),
#   ('T20', 2.0),
#   ('T8', 1.0),
#   ('T14', 1.0),
#   ('MC', 1.5),
#   ('T21', 1.0),
#   ('2', 2.0),
#   ('T43', 0.5),
#   ('T14', 1.0),
#   ('T37', 1.5),
#   ('MC', 1.0),
#   ('T11', 1.0)],
#  'Justin Thomas': [('T7', 1.5),
#   ('T12', 1.5),
#   ('T24', 0.5),
#   ('T8', 1.0),
#   ('T6', 2.0),
#   ('1', 1.0),
#   ('MC', 2.0),
#   ('T56', 1.0),
#   ('T25', 2.0),
#   ('T8', 1.0),
#   ('T11', 1.5),
#   ('T21', 1.0),
#   ('T17', 2.0),
#   ('4', 1.0),
#   ('2', 1.5),
#   ('1', 1.0),
#   ('T9', 1.0),
#   ('T17', 1.0)],
#  'Xander Schauffele': [('T7', 1.5),
#   ('T3', 1.5),
#   ('T49', 0.5),
#   ('MC', 1.0),
#   ('T35', 2.0),
#   ('68', 1.0),
#   ('T2', 2.0),
#   ('T21', 0.5),
#   ('MC', 1.0),
#   ('T6', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T2', 1.5),
#   ('T72', 1.0),
#   ('T32', 1.0),
#   ('T50', 2.0),
#   ('T17', 1.0),
#   ('T18', 1.5),
#   ('T9', 1.0),
#   ('T17', 1.0)],
#  'Rory McIlroy': [('T7', 1.5),
#   ('5', 1.5),
#   ('T12', 0.5),
#   ('T50', 2.0),
#   ('T6', 1.0),
#   ('T2', 2.0),
#   ('T28', 1.0),
#   ('T12', 1.0),
#   ('MC', 2.0),
#   ('T8', 1.0),
#   ('2', 0.5),
#   ('MC', 1.5),
#   ('T16', 1.0),
#   ('T5', 2.0),
#   ('T36', 1.0),
#   ('1', 1.0),
#   ('MC', 1.0),
#   ('T59', 1.0),
#   ('T20', 1.0),
#   ('MC', 1.0)],
#  'Tommy Fleetwood': [('T11', 1.5),
#   ('T8', 1.5),
#   ('T24', 0.5),
#   ('T20', 1.0),
#   ('T35', 2.0),
#   ('T14', 1.0),
#   ('T6', 1.0),
#   ('T12', 2.0),
#   ('2', 2.0),
#   ('T20', 0.5),
#   ('T7', 1.5),
#   ('MC', 1.0),
#   ('T17', 2.0),
#   ('T17', 1.0),
#   ('T26', 1.0),
#   ('T14', 1.5),
#   ('4', 1.0),
#   ('T37', 1.0)],
#  'Gary Woodland': [('T11', 1.5),
#   ('T12', 1.5),
#   ('T24', 0.5),
#   ('T48', 1.0),
#   ('T6', 2.0),
#   ('T17', 1.0),
#   ('T22', 1.0),
#   ('T67', 2.0),
#   ('T36', 2.0),
#   ('T23', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T29', 1.0),
#   ('MC', 1.0),
#   ('T50', 1.5),
#   ('T49', 1.0),
#   ('MC', 1.0),
#   ('1', 1.0)],
#  'Paul Casey': [('T11', 1.5),
#   ('WD', 1.5),
#   ('T21', 0.5),
#   ('T60', 1.0),
#   ('MC', 2.0),
#   ('T31', 1.0),
#   ('T51', 2.0),
#   ('T2', 1.0),
#   ('T16', 2.0),
#   ('T20', 0.5),
#   ('T5', 1.0),
#   ('MC', 1.0),
#   ('T15', 2.0),
#   ('T17', 1.0),
#   ('1', 1.0),
#   ('T12', 1.5),
#   ('T49', 1.0),
#   ('T8', 1.0)],
#  'Jon Rahm': [('T11', 1.5),
#   ('T24', 1.5),
#   ('T43', 0.5),
#   ('MC', 1.0),
#   ('T4', 2.0),
#   ('T17', 1.0),
#   ('MC', 2.0),
#   ('T4', 1.0),
#   ('MC', 2.0),
#   ('T5', 1.0),
#   ('T63', 1.5),
#   ('4', 2.0),
#   ('T52', 1.0),
#   ('T20', 1.5),
#   ('T26', 1.0),
#   ('T11', 1.0)],
#  'Aaron Wise': [('T15', 1.5),
#   ('T16', 1.5),
#   ('T69', 0.5),
#   ('T5', 1.0),
#   ('MC', 2.0),
#   ('T6', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('1', 1.0),
#   ('T2', 1.0),
#   ('T32', 0.5),
#   ('T41', 1.0),
#   ('T68', 1.0),
#   ('T33', 1.0),
#   ('MC', 1.0),
#   ('T15', 1.0)],
#  'Tony Finau': [('T15', 1.5),
#   ('T8', 1.5),
#   ('T4', 0.5),
#   ('2', 1.0),
#   ('T42', 2.0),
#   ('T10', 1.0),
#   ('T37', 1.0),
#   ('T9', 2.0),
#   ('T21', 0.5),
#   ('5', 2.0),
#   ('MC', 1.0),
#   ('T13', 1.0),
#   ('T57', 1.5),
#   ('T21', 1.0),
#   ('T10', 2.0),
#   ('T24', 0.5),
#   ('T17', 1.0),
#   ('MC', 1.0),
#   ('T27', 1.5),
#   ('T2', 1.0),
#   ('MC', 1.0)],
#  'Kyle Stanley': [('T15', 1.5),
#   ('T45', 1.5),
#   ('T12', 0.5),
#   ('T28', 1.0),
#   ('MC', 2.0),
#   ('2', 1.0),
#   ('T39', 2.0),
#   ('MC', 1.0),
#   ('T15', 1.0),
#   ('MC', 2.0),
#   ('T2', 1.0),
#   ('MC', 1.5),
#   ('T13', 1.0),
#   ('52', 2.0),
#   ('T5', 1.0),
#   ('T14', 1.0),
#   ('T25', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Jason Day': [('18', 1.5),
#   ('T24', 1.5),
#   ('MC', 0.5),
#   ('T20', 1.0),
#   ('T19', 2.0),
#   ('T10', 1.0),
#   ('T17', 2.0),
#   ('T12', 1.0),
#   ('MC', 2.0),
#   ('T44', 1.0),
#   ('T5', 1.5),
#   ('1', 1.0),
#   ('T20', 2.0),
#   ('T36', 1.0),
#   ('T22', 1.0),
#   ('T2', 1.0)],
#  'Bryson DeChambeau': [('19', 1.5),
#   ('T19', 1.5),
#   ('1', 0.5),
#   ('1', 1.0),
#   ('MC', 2.0),
#   ('30', 1.0),
#   ('T51', 2.0),
#   ('WD', 1.0),
#   ('T9', 1.0),
#   ('T25', 2.0),
#   ('1', 1.0),
#   ('T42', 1.0),
#   ('T37', 1.5),
#   ('4', 1.0),
#   ('T3', 1.0),
#   ('T38', 2.0),
#   ('2', 1.0),
#   ('WD', 1.0),
#   ('T41', 1.0),
#   ('T55', 1.0),
#   ('T5', 1.0)],
#  'Cameron Smith': [('20', 1.5),
#   ('T65', 1.5),
#   ('3', 0.5),
#   ('T3', 1.0),
#   ('T56', 2.0),
#   ('23', 1.0),
#   ('78', 2.0),
#   ('T42', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('T32', 1.0),
#   ('T5', 2.0),
#   ('T5', 1.0),
#   ('MC', 1.0),
#   ('T46', 1.0),
#   ('T6', 1.0),
#   ('T48', 1.0)],
#  'Patton Kizzire': [('T21', 1.5),
#   ('T61', 1.5),
#   ('T71', 0.5),
#   ('T60', 1.0),
#   ('MC', 2.0),
#   ('T31', 1.0),
#   ('MC', 2.0),
#   ('T30', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T74', 1.0),
#   ('T64', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T36', 1.0),
#   ('MC', 1.0),
#   ('T12', 1.5),
#   ('MC', 1.0),
#   ('T31', 1.0)],
#  'Patrick Cantlay': [('T21', 1.5),
#   ('T55', 1.5),
#   ('T24', 0.5),
#   ('T8', 1.0),
#   ('T27', 2.0),
#   ('T6', 1.0),
#   ('T12', 2.0),
#   ('T15', 1.0),
#   ('T45', 2.0),
#   ('4', 1.0),
#   ('MC', 1.0),
#   ('T23', 1.5),
#   ('T7', 1.0),
#   ('MC', 2.0),
#   ('T17', 1.0),
#   ('T30', 1.5),
#   ('T4', 1.0),
#   ('T35', 1.0)],
#  'Marc Leishman': [('T21', 1.5),
#   ('T41', 1.5),
#   ('T21', 0.5),
#   ('T34', 1.0),
#   ('T71', 2.0),
#   ('T14', 1.0),
#   ('60', 2.0),
#   ('MC', 1.0),
#   ('T45', 2.0),
#   ('T62', 1.0),
#   ('2', 1.0),
#   ('T63', 1.5),
#   ('MC', 1.0),
#   ('9', 2.0),
#   ('T52', 1.0),
#   ('T7', 1.0),
#   ('T37', 1.5),
#   ('MC', 1.0),
#   ('T31', 1.0)],
#  'Francesco Molinari': [('T21', 1.5),
#   ('T8', 1.5),
#   ('MC', 1.0),
#   ('T6', 2.0),
#   ('T39', 1.0),
#   ('1', 2.0),
#   ('T2', 1.0),
#   ('T25', 2.0),
#   ('1', 0.5),
#   ('MC', 1.5),
#   ('T16', 1.0),
#   ('49', 1.0),
#   ('T20', 2.0),
#   ('T17', 1.0),
#   ('T26', 1.0),
#   ('T25', 1.5),
#   ('MC', 1.0),
#   ('T40', 1.0)],
#  'Kevin Na': [('25', 1.5),
#   ('T12', 1.5),
#   ('MC', 0.5),
#   ('T15', 1.0),
#   ('T19', 2.0),
#   ('T31', 1.0),
#   ('T51', 2.0),
#   ('1', 0.5),
#   ('MC', 1.0),
#   ('4', 1.0),
#   ('T6', 1.0),
#   ('T46', 1.5),
#   ('MC', 1.0),
#   ('T52', 1.0),
#   ('T36', 1.0),
#   ('T2', 1.0),
#   ('T20', 1.0),
#   ('T48', 1.0)],
#  'Keegan Bradley': [('T26', 1.5),
#   ('1', 1.5),
#   ('T49', 0.5),
#   ('T34', 1.0),
#   ('T42', 2.0),
#   ('4', 1.0),
#   ('79', 2.0),
#   ('T13', 0.5),
#   ('T47', 1.0),
#   ('MC', 2.0),
#   ('T23', 1.0),
#   ('T7', 1.5),
#   ('T76', 1.0),
#   ('T43', 0.5),
#   ('T36', 1.0),
#   ('T26', 1.0),
#   ('T31', 1.0),
#   ('T49', 1.0),
#   ('MC', 1.0),
#   ('T43', 1.0)],
#  'Brooks Koepka': [('T26', 1.5),
#   ('T19', 1.5),
#   ('T12', 0.5),
#   ('T8', 1.0),
#   ('1', 2.0),
#   ('5', 1.0),
#   ('MC', 1.0),
#   ('T39', 2.0),
#   ('T19', 1.0),
#   ('1', 2.0),
#   ('T30', 1.0),
#   ('2', 1.0),
#   ('T11', 1.5),
#   ('T42', 1.0)],
#  'Patrick Reed': [('28', 1.5),
#   ('T19', 1.5),
#   ('T35', 0.5),
#   ('T25', 1.0),
#   ('MC', 2.0),
#   ('T28', 1.0),
#   ('T28', 2.0),
#   ('T23', 1.0),
#   ('MC', 1.0),
#   ('4', 2.0),
#   ('T29', 1.0),
#   ('T41', 1.5),
#   ('8', 1.0),
#   ('1', 2.0),
#   ('T9', 1.0),
#   ('T7', 1.0),
#   ('T2', 1.0),
#   ('T37', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T17', 1.0)],
#  'Bubba Watson': [('29', 1.5),
#   ('T16', 1.5),
#   ('T7', 0.5),
#   ('T34', 1.0),
#   ('MC', 2.0),
#   ('T31', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T13', 0.5),
#   ('1', 1.0),
#   ('MC', 2.0),
#   ('T44', 1.0),
#   ('T57', 1.5),
#   ('T5', 2.0),
#   ('1', 1.0),
#   ('T66', 1.0),
#   ('T9', 1.5),
#   ('1', 1.0),
#   ('T35', 1.0),
#   ('T40', 1.0)],
#  'Phil Mickelson': [('30', 1.5),
#   ('T58', 1.5),
#   ('T12', 0.5),
#   ('T15', 1.0),
#   ('MC', 2.0),
#   ('T24', 1.0),
#   ('T24', 2.0),
#   ('MC', 1.0),
#   ('T65', 0.5),
#   ('T48', 2.0),
#   ('T12', 1.0),
#   ('T13', 1.0),
#   ('MC', 1.5),
#   ('T5', 1.0),
#   ('T36', 2.0),
#   ('T24', 0.5),
#   ('T17', 1.0),
#   ('1', 1.5),
#   ('T6', 1.0),
#   ('T2', 1.0),
#   ('T5', 1.0)],
#  'Andrew Putnam': [('T16', 1.5),
#   ('T49', 0.5),
#   ('T78', 1.0),
#   ('T59', 2.0),
#   ('T8', 1.0),
#   ('79', 1.0),
#   ('MC', 0.5),
#   ('2', 1.0),
#   ('T20', 1.0),
#   ('T42', 1.0),
#   ('T82', 1.0),
#   ('T32', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Jason Kokrak': [('T19', 1.5),
#   ('T24', 0.5),
#   ('T40', 1.0),
#   ('T57', 1.0),
#   ('T19', 2.0),
#   ('T12', 1.0),
#   ('MC', 2.0),
#   ('T3', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T32', 1.0),
#   ('T46', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T80', 0.5),
#   ('MC', 1.0),
#   ('T8', 1.0),
#   ('T20', 1.0),
#   ('T35', 1.0),
#   ('T31', 1.0)],
#  'Adam Hadwin': [('T19', 1.5),
#   ('T21', 0.5),
#   ('T11', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('T35', 2.0),
#   ('T42', 1.0),
#   ('MC', 2.0),
#   ('T74', 1.0),
#   ('T52', 1.0),
#   ('T57', 1.5),
#   ('T16', 1.0),
#   ('T24', 2.0),
#   ('T17', 1.0),
#   ('T12', 1.0),
#   ('T9', 1.5),
#   ('T6', 1.0),
#   ('T43', 1.0)],
#  'Alex Noren': [('T24', 1.5),
#   ('T43', 0.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T31', 1.0),
#   ('T17', 2.0),
#   ('T25', 2.0),
#   ('T3', 0.5),
#   ('T17', 1.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('3', 1.0),
#   ('T36', 1.0),
#   ('T14', 1.5),
#   ('3', 1.0),
#   ('T16', 1.0),
#   ('T21', 1.0)],
#  'Charles Howell III': [('T24', 1.5),
#   ('T58', 0.5),
#   ('MC', 1.0),
#   ('T71', 2.0),
#   ('MC', 2.0),
#   ('T30', 0.5),
#   ('T25', 2.0),
#   ('T26', 1.0),
#   ('T65', 1.0),
#   ('T9', 1.0),
#   ('T17', 1.5),
#   ('T21', 1.0),
#   ('T55', 1.0),
#   ('T18', 0.5),
#   ('T9', 1.0),
#   ('T14', 1.0),
#   ('T40', 1.0),
#   ('MC', 1.0),
#   ('T37', 1.0)],
#  'Henrik Stenson': [('T29', 1.5),
#   ('T69', 0.5),
#   ('T20', 1.0),
#   ('MC', 2.0),
#   ('T39', 1.0),
#   ('T35', 2.0),
#   ('T6', 2.0),
#   ('T26', 1.0),
#   ('T13', 1.0),
#   ('T23', 1.5),
#   ('T5', 2.0),
#   ('T6', 0.5),
#   ('4', 1.0),
#   ('MC', 1.0)],
#  'Austin Cook': [('T29', 1.5),
#   ('T62', 0.5),
#   ('T60', 1.0),
#   ('T50', 2.0),
#   ('T53', 1.0),
#   ('T28', 2.0),
#   ('T34', 1.0),
#   ('T5', 0.5),
#   ('MC', 1.0),
#   ('T6', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T46', 1.5),
#   ('T34', 1.0),
#   ('T50', 1.0),
#   ('MC', 2.0),
#   ('T36', 1.0),
#   ('T40', 1.0),
#   ('T49', 1.0),
#   ('MC', 1.0),
#   ('T31', 1.0)],
#  'Tyrrell Hatton': [('T29', 1.5),
#   ('T12', 0.5),
#   ('T20', 1.0),
#   ('T10', 2.0),
#   ('T28', 1.0),
#   ('T51', 2.0),
#   ('T9', 1.0),
#   ('T6', 2.0),
#   ('MC', 0.5),
#   ('MC', 1.5),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('T44', 2.0),
#   ('T9', 1.0),
#   ('T69', 1.0),
#   ('T3', 1.5),
#   ('MC', 1.0)],
#  'Byeong Hun An': [('T29', 1.5),
#   ('T31', 0.5),
#   ('T40', 1.0),
#   ('T56', 2.0),
#   ('T57', 1.0),
#   ('T2', 1.0),
#   ('T51', 2.0),
#   ('67', 2.0),
#   ('MC', 1.0),
#   ('T2', 1.0),
#   ('T15', 0.5),
#   ('T30', 1.5),
#   ('T63', 1.0),
#   ('T7', 1.0),
#   ('T52', 0.5),
#   ('T14', 1.0),
#   ('MC', 1.0),
#   ('T5', 1.0),
#   ('T23', 1.0)],
#  'Beau Hossler': [('T33', 1.5),
#   ('T35', 0.5),
#   ('T60', 1.0),
#   ('MC', 2.0),
#   ('T75', 2.0),
#   ('T2', 1.0),
#   ('T44', 1.0),
#   ('T64', 1.0),
#   ('T32', 1.0),
#   ('T46', 1.5),
#   ('T34', 1.0),
#   ('T16', 1.0),
#   ('2', 0.5),
#   ('T66', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T43', 1.0),
#   ('T17', 1.0)],
#  'Zach Johnson': [('T33', 1.5),
#   ('MC', 0.5),
#   ('T40', 1.0),
#   ('T19', 2.0),
#   ('T17', 1.0),
#   ('T17', 2.0),
#   ('T16', 1.0),
#   ('T19', 1.0),
#   ('T12', 2.0),
#   ('T40', 1.0),
#   ('MC', 1.0),
#   ('T75', 1.5),
#   ('T42', 1.0),
#   ('T36', 2.0),
#   ('T36', 1.0),
#   ('T26', 1.0),
#   ('T16', 1.0),
#   ('T57', 1.0)],
#  'Ted Potter Jr': [('T35', 1.5),
#   ('T66', 0.5),
#   ('T40', 1.0),
#   ('T71', 2.0),
#   ('T48', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T57', 1.0),
#   ('T42', 1.0),
#   ('T41', 1.5),
#   ('T27', 1.0),
#   ('T16', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('1', 1.0)],
#  'Brice Garnett': [('T35', 1.5),
#   ('T12', 0.5),
#   ('MC', 1.0),
#   ('T20', 1.0),
#   ('T50', 2.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T56', 1.0),
#   ('T62', 1.0),
#   ('MC', 1.0),
#   ('T41', 1.5),
#   ('75', 1.0),
#   ('T42', 1.0),
#   ('MC', 0.5),
#   ('T31', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T35', 1.0)],
#  'Andrew Landry': [('T35', 1.5),
#   ('T58', 0.5),
#   ('T76', 1.0),
#   ('T50', 2.0),
#   ('T57', 1.0),
#   ('MC', 2.0),
#   ('T55', 1.0),
#   ('MC', 1.0),
#   ('T65', 1.0),
#   ('MC', 1.0),
#   ('T67', 1.5),
#   ('WD', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'C.T. Pan': [('T38', 1.5),
#   ('T4', 0.5),
#   ('T60', 1.0),
#   ('T2', 1.0),
#   ('T34', 1.0),
#   ('T39', 0.5),
#   ('MC', 1.0),
#   ('T18', 1.0),
#   ('T20', 1.0),
#   ('T32', 1.0),
#   ('T46', 1.5),
#   ('T76', 1.0),
#   ('T23', 1.0),
#   ('MC', 0.5),
#   ('T41', 1.0),
#   ('MC', 1.0),
#   ('T17', 1.0),
#   ('MC', 1.0),
#   ('T62', 1.0)],
#  'Peter Uihlein': [('T38', 1.5),
#   ('T12', 0.5),
#   ('T48', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('T12', 1.0),
#   ('T48', 2.0),
#   ('T43', 1.0),
#   ('5', 1.0),
#   ('T21', 1.0),
#   ('T5', 1.0),
#   ('MC', 0.5),
#   ('T17', 1.0),
#   ('T66', 1.0),
#   ('T37', 1.5),
#   ('MC', 1.0),
#   ('T26', 1.0),
#   ('T52', 1.0)],
#  'Chez Reavie': [('T38', 1.5),
#   ('MC', 0.5),
#   ('T20', 1.0),
#   ('T12', 2.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T6', 1.0),
#   ('MC', 1.0),
#   ('T30', 1.5),
#   ('53', 2.0),
#   ('MC', 0.5),
#   ('T29', 1.0),
#   ('MC', 1.0),
#   ('T52', 1.5),
#   ('T73', 1.0),
#   ('T2', 1.0),
#   ('2', 1.0)],
#  'Chris Kirk': [('T41', 1.5),
#   ('T35', 0.5),
#   ('T78', 1.0),
#   ('T11', 1.0),
#   ('T31', 2.0),
#   ('76', 1.0),
#   ('T23', 1.0),
#   ('T6', 1.0),
#   ('T52', 1.0),
#   ('T11', 1.0),
#   ('T46', 1.5),
#   ('T55', 1.0),
#   ('MC', 0.5),
#   ('13', 1.0),
#   ('T49', 1.0),
#   ('T33', 1.0),
#   ('MC', 1.0),
#   ('T11', 1.0)],
#  'Rafa Cabrera Bello': [('T41', 1.5),
#   ('T7', 0.5),
#   ('T60', 1.0),
#   ('T11', 1.0),
#   ('T10', 2.0),
#   ('T17', 1.0),
#   ('74', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T36', 2.0),
#   ('T8', 0.5),
#   ('T17', 1.5),
#   ('T38', 2.0),
#   ('MC', 0.5),
#   ('T36', 1.0),
#   ('T3', 1.5),
#   ('T29', 1.0),
#   ('T26', 1.0),
#   ('T26', 1.0)],
#  'Siwoo Kim': [('T41', 1.5),
#   ('T35', 0.5),
#   ('T76', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T10', 1.0),
#   ('T29', 1.0),
#   ('T67', 2.0),
#   ('MC', 1.0),
#   ('T26', 1.0),
#   ('MC', 2.0),
#   ('T29', 1.0),
#   ('T66', 1.0),
#   ('T63', 1.5),
#   ('2', 1.0),
#   ('T24', 2.0),
#   ('T9', 1.0),
#   ('MC', 1.0),
#   ('T59', 1.0),
#   ('MC', 1.0),
#   ('T62', 1.0)],
#  'Keith Mitchell': [('T45', 1.5),
#   ('20', 0.5),
#   ('MC', 1.0),
#   ('T41', 1.0),
#   ('T65', 1.0),
#   ('T7', 1.0),
#   ('T30', 0.5),
#   ('T56', 1.0),
#   ('T37', 1.0),
#   ('MC', 1.0),
#   ('T3', 1.0),
#   ('T77', 1.5),
#   ('T34', 1.0),
#   ('T55', 1.0),
#   ('T6', 0.5),
#   ('MC', 1.0),
#   ('T47', 1.0)],
#  'J.J Spaun': [('T45', 1.5),
#   ('T66', 0.5),
#   ('T60', 1.0),
#   ('T35', 2.0),
#   ('MC', 1.0),
#   ('T13', 0.5),
#   ('T47', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T3', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('WD', 1.0)],
#  'Scott Piercy': [('T45', 1.5),
#   ('DQ', 0.5),
#   ('T48', 1.0),
#   ('T45', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('T74', 0.5),
#   ('T45', 2.0),
#   ('WD', 1.0),
#   ('MC', 1.0),
#   ('T32', 1.0),
#   ('MC', 1.5),
#   ('T16', 1.0),
#   ('T24', 0.5),
#   ('MC', 1.0),
#   ('T17', 1.0),
#   ('T20', 1.0),
#   ('MC', 1.0)],
#  'Luke List': [('T45', 1.5),
#   ('MC', 0.5),
#   ('T48', 1.0),
#   ('MC', 2.0),
#   ('T24', 1.0),
#   ('T39', 2.0),
#   ('T3', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T56', 1.0),
#   ('T37', 1.0),
#   ('MC', 1.5),
#   ('T9', 1.0),
#   ('T3', 1.0),
#   ('T24', 0.5),
#   ('T59', 1.0),
#   ('T7', 1.0),
#   ('T16', 1.0),
#   ('2', 1.0),
#   ('T26', 1.0),
#   ('T26', 1.0)],
#  'Brian Gay': [('T45', 1.5),
#   ('T62', 0.5),
#   ('70', 1.0),
#   ('T6', 1.0),
#   ('79', 2.0),
#   ('MC', 1.0),
#   ('T39', 0.5),
#   ('T20', 2.0),
#   ('T12', 1.0),
#   ('T44', 1.0),
#   ('12', 1.0),
#   ('T72', 1.5),
#   ('T70', 1.0),
#   ('T22', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T8', 1.0),
#   ('T9', 1.0)],
#  'Ian Poulter': [('T51', 1.5),
#   ('MC', 0.5),
#   ('T48', 1.0),
#   ('T31', 2.0),
#   ('T10', 1.0),
#   ('T12', 1.0),
#   ('MC', 2.0),
#   ('T30', 1.0),
#   ('T25', 2.0),
#   ('T20', 0.5),
#   ('T11', 1.5),
#   ('T7', 1.0),
#   ('T44', 2.0),
#   ('1', 0.5),
#   ('T5', 1.0),
#   ('T41', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T52', 1.0)],
#  'Adam Scott': [('T51', 1.5),
#   ('T49', 0.5),
#   ('T5', 1.0),
#   ('3', 2.0),
#   ('T57', 1.0),
#   ('T17', 2.0),
#   ('MC', 2.0),
#   ('T35', 1.0),
#   ('T52', 1.0),
#   ('T9', 1.0),
#   ('T11', 1.5),
#   ('T76', 1.0),
#   ('T32', 2.0),
#   ('T41', 1.0),
#   ('T16', 1.0),
#   ('T13', 1.0),
#   ('T53', 1.0),
#   ('MC', 1.0)],
#  'Ryan Armour': [('T51', 1.5),
#   ('T35', 0.5),
#   ('T78', 1.0),
#   ('T8', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T21', 0.5),
#   ('T56', 1.0),
#   ('T23', 1.0),
#   ('T14', 1.0),
#   ('T59', 1.0),
#   ('MC', 1.5),
#   ('T55', 1.0),
#   ('T43', 0.5),
#   ('77', 1.0),
#   ('T40', 1.0),
#   ('MC', 1.0),
#   ('T64', 1.0),
#   ('T20', 1.0),
#   ('MC', 1.0)],
#  'Abraham Ancer': [('T51', 1.5),
#   ('T7', 0.5),
#   ('MC', 1.0),
#   ('T24', 1.0),
#   ('5', 1.0),
#   ('MC', 2.0),
#   ('T47', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T57', 1.0),
#   ('T52', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('T8', 0.5),
#   ('T16', 1.0),
#   ('T52', 1.5),
#   ('MC', 1.0),
#   ('T68', 1.0)],
#  'Jordan Spieth': [('T55', 1.5),
#   ('T12', 0.5),
#   ('T25', 1.0),
#   ('T12', 2.0),
#   ('T60', 1.0),
#   ('T9', 2.0),
#   ('T42', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('T32', 1.0),
#   ('T21', 1.0),
#   ('T41', 1.5),
#   ('3', 2.0),
#   ('T3', 0.5),
#   ('T17', 1.0),
#   ('MC', 1.0),
#   ('T14', 1.5),
#   ('T9', 1.0),
#   ('T20', 1.0),
#   ('MC', 1.0)],
#  'Pat Perez': [('T55', 1.5),
#   ('WD', 0.5),
#   ('T40', 1.0),
#   ('T35', 2.0),
#   ('T63', 1.0),
#   ('T17', 2.0),
#   ('MC', 1.0),
#   ('T36', 2.0),
#   ('T70', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.5),
#   ('MC', 2.0),
#   ('T52', 1.0),
#   ('T20', 1.5),
#   ('T41', 1.0),
#   ('T35', 1.0)],
#  'Louis Oosthuizen': [('T58', 1.5),
#   ('T31', 0.5),
#   ('T28', 1.0),
#   ('T24', 1.0),
#   ('T28', 2.0),
#   ('T16', 2.0),
#   ('T13', 1.0),
#   ('T5', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('T12', 2.0),
#   ('T9', 1.0),
#   ('MC', 1.0),
#   ('T16', 1.0),
#   ('T30', 1.5),
#   ('T24', 1.0)],
#  'Kevin Kisner': [('T58', 1.5),
#   ('T24', 0.5),
#   ('T73', 1.0),
#   ('T12', 2.0),
#   ('T39', 1.0),
#   ('MC', 1.0),
#   ('T2', 2.0),
#   ('55', 0.5),
#   ('MC', 2.0),
#   ('T74', 1.0),
#   ('T52', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('T7', 1.0),
#   ('T28', 2.0),
#   ('2', 1.0),
#   ('MC', 1.0),
#   ('29', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Chesson Hadley': [('T61', 1.5),
#   ('MC', 0.5),
#   ('T56', 1.0),
#   ('T45', 1.0),
#   ('MC', 2.0),
#   ('MC', 2.0),
#   ('T72', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T40', 1.0),
#   ('T20', 1.0),
#   ('T11', 1.5),
#   ('T16', 1.0),
#   ('T7', 1.0),
#   ('T18', 0.5),
#   ('T49', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T35', 1.0),
#   ('T5', 1.0)],
#  'Emiliano Grillo': [('T61', 1.5),
#   ('T7', 0.5),
#   ('T48', 1.0),
#   ('T31', 2.0),
#   ('T66', 1.0),
#   ('MC', 2.0),
#   ('T19', 1.0),
#   ('MC', 2.0),
#   ('T23', 1.0),
#   ('3', 1.0),
#   ('T37', 1.5),
#   ('T9', 1.0),
#   ('T16', 1.0),
#   ('T3', 0.5),
#   ('T26', 1.0),
#   ('T8', 1.0),
#   ('T57', 1.0)],
#  'Brendan Steele': [('64', 1.5),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T60', 1.0),
#   ('T47', 2.0),
#   ('MC', 1.0),
#   ('63', 2.0),
#   ('T79', 1.5),
#   ('MC', 2.0),
#   ('T17', 1.0),
#   ('T20', 1.5),
#   ('T49', 1.0),
#   ('T3', 1.0)],
#  'Ryan Palmer': [('T65', 1.5),
#   ('MC', 0.5),
#   ('T5', 1.0),
#   ('T22', 1.0),
#   ('T77', 1.0),
#   ('MC', 1.0),
#   ('T51', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T23', 1.5),
#   ('76', 1.0),
#   ('MC', 0.5),
#   ('T28', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Brandt Snedeker': [('67', 1.5),
#   ('T31', 0.5),
#   ('1', 1.0),
#   ('T42', 2.0),
#   ('T8', 1.0),
#   ('MC', 2.0),
#   ('T3', 0.5),
#   ('MC', 1.0),
#   ('T48', 2.0),
#   ('T6', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('T23', 1.0),
#   ('T87', 0.5),
#   ('MC', 1.0),
#   ('T31', 1.0),
#   ('MC', 1.0),
#   ('T20', 1.0),
#   ('T23', 1.0)],
#  'Brian Harman': [('68', 1.5),
#   ('T49', 0.5),
#   ('T48', 1.0),
#   ('T71', 2.0),
#   ('62', 1.0),
#   ('MC', 2.0),
#   ('T56', 0.5),
#   ('T6', 1.0),
#   ('T36', 2.0),
#   ('T14', 1.0),
#   ('MC', 1.5),
#   ('74', 1.0),
#   ('T23', 1.0),
#   ('T44', 2.0),
#   ('T9', 1.0),
#   ('T54', 1.0),
#   ('T5', 1.5),
#   ('T33', 1.0)],
#  'Brian Stuard': [('T31', 0.5),
#   ('T25', 1.0),
#   ('MC', 1.0),
#   ('T37', 1.0),
#   ('81', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('T70', 1.0),
#   ('T32', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('T67', 1.0),
#   ('MC', 0.5),
#   ('T36', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T65', 1.0)],
#  'Kevin Chappell': [('T35', 0.5),
#   ('MC', 1.0),
#   ('T65', 2.0),
#   ('T39', 1.0),
#   ('T6', 2.0),
#   ('MC', 1.0),
#   ('T30', 0.5),
#   ('65', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T36', 1.0),
#   ('T7', 1.0),
#   ('T30', 1.5),
#   ('T20', 1.0),
#   ('T8', 1.0),
#   ('T31', 1.0)],
#  'James Hahn': [('T35', 0.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T50', 1.0),
#   ('MC', 0.5),
#   ('T36', 1.0),
#   ('T45', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T32', 0.5),
#   ('T36', 1.0),
#   ('T58', 1.0),
#   ('T14', 1.0),
#   ('T26', 1.0),
#   ('T11', 1.0)],
#  'Daniel Berger': [('T35', 0.5),
#   ('T15', 1.0),
#   ('MC', 1.0),
#   ('T12', 2.0),
#   ('T48', 1.0),
#   ('MC', 2.0),
#   ('T67', 1.0),
#   ('T6', 2.0),
#   ('MC', 1.0),
#   ('T57', 1.5),
#   ('T55', 1.0),
#   ('T32', 2.0),
#   ('T18', 0.5),
#   ('T59', 1.0),
#   ('T14', 1.5),
#   ('T29', 1.0),
#   ('MC', 1.0),
#   ('T11', 1.0)],
#  'Kevin Tway': [('T43', 0.5),
#   ('T56', 1.0),
#   ('T11', 1.0),
#   ('T17', 1.0),
#   ('T50', 1.0),
#   ('T6', 1.0),
#   ('MC', 1.0),
#   ('T65', 1.0),
#   ('T5', 1.0),
#   ('T9', 1.0),
#   ('T46', 1.5),
#   ('MC', 1.0),
#   ('T67', 1.0),
#   ('T32', 0.5),
#   ('T58', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T57', 1.0)],
#  'Branden Grace': [('T43', 0.5),
#   ('MC', 1.0),
#   ('T27', 2.0),
#   ('T63', 1.0),
#   ('MC', 2.0),
#   ('T25', 2.0),
#   ('T52', 1.0),
#   ('T5', 0.5),
#   ('T3', 1.0),
#   ('T46', 1.5),
#   ('T24', 2.0),
#   ('T29', 1.0),
#   ('T8', 1.0),
#   ('T30', 1.5),
#   ('T37', 1.0),
#   ('T20', 1.0)],
#  'Russell Knox': [('T43', 0.5),
#   ('MC', 1.0),
#   ('T35', 2.0),
#   ('T48', 1.0),
#   ('MC', 2.0),
#   ('T49', 1.0),
#   ('1', 1.0),
#   ('T38', 1.0),
#   ('T12', 2.0),
#   ('T44', 1.0),
#   ('T20', 1.0),
#   ('T16', 1.0),
#   ('MC', 1.5),
#   ('T40', 1.0),
#   ('MC', 0.5),
#   ('T73', 1.0),
#   ('T16', 1.0),
#   ('MC', 1.0),
#   ('T15', 1.0),
#   ('MC', 1.0)],
#  'Matt Kuchar': [('T43', 0.5),
#   ('T60', 1.0),
#   ('MC', 2.0),
#   ('T14', 1.0),
#   ('MC', 1.0),
#   ('T9', 2.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T13', 1.0),
#   ('T32', 1.0),
#   ('MC', 1.0),
#   ('T17', 1.5),
#   ('T23', 1.0),
#   ('T28', 2.0),
#   ('T8', 0.5),
#   ('T9', 1.0),
#   ('T40', 1.0),
#   ('T58', 1.5),
#   ('T26', 1.0),
#   ('T62', 1.0),
#   ('T5', 1.0)],
#  'J.B. Holmes': [('T49', 0.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T61', 1.0),
#   ('MC', 0.5),
#   ('T2', 1.0),
#   ('3', 1.0),
#   ('T13', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.5),
#   ('T42', 1.0),
#   ('T32', 0.5),
#   ('T41', 1.0),
#   ('T46', 1.0),
#   ('T49', 1.0),
#   ('T60', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Danny Lee': [('T49', 0.5),
#   ('T34', 1.0),
#   ('T24', 1.0),
#   ('T6', 1.0),
#   ('DQ', 1.0),
#   ('MC', 0.5),
#   ('T15', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T14', 1.0),
#   ('T7', 1.5),
#   ('MC', 1.0),
#   ('T55', 1.0),
#   ('T64', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('WD', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Scott Stallings': [('T49', 0.5),
#   ('T28', 1.0),
#   ('MC', 1.0),
#   ('T45', 1.0),
#   ('MC', 1.0),
#   ('T13', 0.5),
#   ('T38', 1.0),
#   ('MC', 2.0),
#   ('T30', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('T55', 1.0),
#   ('T80', 0.5),
#   ('MC', 1.0),
#   ('T31', 1.0),
#   ('T29', 1.0),
#   ('T4', 1.0),
#   ('7', 1.0),
#   ('T23', 1.0)],
#  'Bronson Burgoon': [('T58', 0.5),
#   ('T11', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T2', 1.0),
#   ('T30', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T16', 1.0),
#   ('MC', 1.0),
#   ('T24', 0.5),
#   ('MC', 1.0),
#   ('T47', 1.0)],
#  'Russell Henley': [('T58', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T50', 2.0),
#   ('MC', 2.0),
#   ('10', 0.5),
#   ('T6', 1.0),
#   ('T25', 2.0),
#   ('T29', 1.0),
#   ('T58', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('T15', 2.0),
#   ('T8', 0.5),
#   ('T36', 1.0),
#   ('T58', 1.5),
#   ('T24', 1.0),
#   ('T15', 1.0),
#   ('MC', 1.0)],
#  'Stewart Cink': [('T62', 0.5),
#   ('MC', 1.0),
#   ('T4', 2.0),
#   ('T37', 1.0),
#   ('T24', 2.0),
#   ('T2', 1.0),
#   ('T4', 1.0),
#   ('MC', 1.0),
#   ('T58', 1.0),
#   ('MC', 1.5),
#   ('T72', 1.0),
#   ('T42', 1.0),
#   ('T58', 1.0),
#   ('T31', 1.0),
#   ('T46', 1.0),
#   ('MC', 1.0)],
#  'Nick Watney': [('T62', 0.5),
#   ('T11', 1.0),
#   ('MC', 1.0),
#   ('T71', 2.0),
#   ('T29', 1.0),
#   ('T60', 1.0),
#   ('T30', 0.5),
#   ('MC', 1.0),
#   ('T57', 1.0),
#   ('MC', 1.0),
#   ('T37', 1.5),
#   ('T2', 1.0),
#   ('T32', 1.0),
#   ('T32', 0.5),
#   ('T59', 1.0),
#   ('T33', 1.0),
#   ('T47', 1.0),
#   ('T26', 1.0)],
#  'Tom Hoge': [('T66', 0.5),
#   ('MC', 1.0),
#   ('T20', 1.0),
#   ('MC', 1.0),
#   ('T69', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T13', 1.0),
#   ('T42', 1.0),
#   ('T72', 1.5),
#   ('T76', 1.0),
#   ('T55', 1.0),
#   ('T60', 0.5),
#   ('T26', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T53', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Jimmy Walker': [('T71', 0.5),
#   ('T71', 1.0),
#   ('T42', 2.0),
#   ('T29', 1.0),
#   ('MC', 2.0),
#   ('MC', 0.5),
#   ('T56', 2.0),
#   ('T20', 1.0),
#   ('T6', 1.0),
#   ('T2', 1.5),
#   ('T20', 2.0),
#   ('T73', 1.0),
#   ('T28', 1.0),
#   ('T33', 1.0),
#   ('MC', 1.0),
#   ('T8', 1.0)],
#  'Ryan Moore': [('T71', 0.5),
#   ('MC', 1.0),
#   ('T6', 1.0),
#   ('T59', 2.0),
#   ('T12', 2.0),
#   ('T55', 1.0),
#   ('T13', 0.5),
#   ('MC', 1.0),
#   ('T13', 1.0),
#   ('T30', 1.5),
#   ('MC', 1.0),
#   ('T16', 1.0),
#   ('T28', 2.0),
#   ('T5', 1.0),
#   ('MC', 1.0),
#   ('T49', 1.0),
#   ('T9', 1.0),
#   ('MC', 1.0)],
#  'Charley Hoffman': [('74', 0.5),
#   ('T20', 1.0),
#   ('MC', 2.0),
#   ('T53', 1.0),
#   ('T29', 1.0),
#   ('T17', 2.0),
#   ('T19', 1.0),
#   ('T15', 1.0),
#   ('T20', 2.0),
#   ('MC', 1.0),
#   ('T52', 1.0),
#   ('MC', 1.5),
#   ('T23', 1.0),
#   ('T12', 2.0),
#   ('T36', 1.0),
#   ('T14', 1.0),
#   ('MC', 1.0),
#   ('T20', 1.5),
#   ('T41', 1.0),
#   ('WD', 1.0),
#   ('T26', 1.0)],
#  'Meenwhee Kim': [('75', 0.5),
#   ('T48', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T2', 1.0),
#   ('T16', 1.0),
#   ('T74', 0.5),
#   ('T29', 1.0),
#   ('T58', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('T50', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T49', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Jamie Lovemark': [('76', 0.5),
#   ('T34', 1.0),
#   ('T24', 1.0),
#   ('MC', 2.0),
#   ('T50', 1.0),
#   ('T26', 0.5),
#   ('T19', 1.0),
#   ('T37', 1.0),
#   ('T17', 1.5),
#   ('MC', 1.0),
#   ('T24', 0.5),
#   ('T41', 1.0),
#   ('T16', 1.0),
#   ('7', 1.0),
#   ('T26', 1.0),
#   ('T52', 1.0)],
#  'Jhonattan Vegas': [('MC', 0.5),
#   ('T15', 1.0),
#   ('MC', 1.0),
#   ('T59', 2.0),
#   ('T53', 1.0),
#   ('T29', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('T41', 2.0),
#   ('T40', 1.0),
#   ('73', 1.0),
#   ('T41', 1.5),
#   ('T42', 1.0),
#   ('T38', 2.0),
#   ('T87', 0.5),
#   ('T52', 1.0),
#   ('T20', 1.5),
#   ('T72', 1.0),
#   ('MC', 1.0)],
#  'Kelly Kraft': [('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T50', 1.0),
#   ('MC', 2.0),
#   ('T63', 1.0),
#   ('2', 0.5),
#   ('T47', 1.0),
#   ('66', 1.0),
#   ('T35', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T80', 0.5),
#   ('T31', 1.0),
#   ('T8', 1.0),
#   ('63', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Troy Merritt': [('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T50', 1.0),
#   ('T43', 1.0),
#   ('MC', 1.0),
#   ('T12', 1.0),
#   ('T53', 1.0),
#   ('T42', 1.0),
#   ('T43', 0.5),
#   ('MC', 1.0),
#   ('T49', 1.0),
#   ('T41', 1.0),
#   ('T8', 1.0)],
#  'Ollie Schniederjans': [('MC', 0.5),
#   ('MC', 1.0),
#   ('T57', 1.0),
#   ('T59', 2.0),
#   ('MC', 1.0),
#   ('T26', 0.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T65', 1.0),
#   ('T74', 1.0),
#   ('T75', 1.5),
#   ('T34', 1.0),
#   ('T42', 1.0),
#   ('T41', 1.0),
#   ('T49', 1.0),
#   ('T64', 1.0),
#   ('MC', 1.0),
#   ('T3', 1.0)],
#  'Anirban Lahiri': [('MC', 0.5),
#   ('T71', 1.0),
#   ('MC', 2.0),
#   ('T6', 1.0),
#   ('MC', 2.0),
#   ('T39', 0.5),
#   ('T9', 1.0),
#   ('T37', 1.0),
#   ('T58', 1.0),
#   ('T26', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T75', 1.0),
#   ('T59', 1.0),
#   ('T26', 1.0),
#   ('MC', 1.0)],
#  'Michael Kim': [('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T35', 2.0),
#   ('1', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T18', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('77', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T57', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Satoshi Kodaira': [('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T59', 2.0),
#   ('T63', 1.0),
#   ('T35', 2.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('T20', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('1', 1.0),
#   ('T28', 2.0),
#   ('T59', 1.0),
#   ('MC', 1.0),
#   ('54', 1.5)],
#  'Joel Dahmen': [('MC', 0.5),
#   ('MC', 1.0),
#   ('T8', 1.0),
#   ('T2', 1.0),
#   ('T5', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T20', 1.0),
#   ('T16', 1.0),
#   ('T16', 1.0),
#   ('T76', 0.5),
#   ('T33', 1.0),
#   ('MC', 1.0),
#   ('T55', 1.0)],
#  'Kevin Streelman': [('MC', 0.5),
#   ('T40', 1.0),
#   ('MC', 2.0),
#   ('T7', 1.0),
#   ('MC', 0.5),
#   ('T33', 1.0),
#   ('T44', 1.0),
#   ('76', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('T7', 1.0),
#   ('T43', 0.5),
#   ('T41', 1.0),
#   ('MC', 1.0),
#   ('T41', 1.0),
#   ('6', 1.0),
#   ('T40', 1.0)],
#  'Jason Dufner': [('MC', 0.5),
#   ('MC', 1.0),
#   ('T66', 1.0),
#   ('MC', 2.0),
#   ('T51', 2.0),
#   ('T25', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T5', 1.5),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T64', 0.5),
#   ('T17', 1.0),
#   ('MC', 1.0),
#   ('T55', 1.5),
#   ('T17', 1.0)],
#  'Sam Ryder': [('T28', 1.0),
#   ('T45', 1.0),
#   ('78', 1.0),
#   ('T2', 1.0),
#   ('MC', 0.5),
#   ('T26', 1.0),
#   ('MC', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('5', 0.5),
#   ('T68', 1.0),
#   ('T68', 1.0)],
#  "Sean O'Hair": [('T28', 1.0),
#   ('MC', 1.0),
#   ('T71', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('WD', 1.5),
#   ('T63', 1.0),
#   ('MC', 1.0),
#   ('T64', 0.5),
#   ('T7', 1.0),
#   ('T12', 1.0),
#   ('MC', 1.0),
#   ('T64', 1.0),
#   ('T73', 1.0)],
#  'Seamus Power': [('T34', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T16', 1.0),
#   ('MC', 0.5),
#   ('T36', 1.0),
#   ('T12', 1.0),
#   ('DQ', 1.0),
#   ('MC', 1.0),
#   ('T27', 1.0),
#   ('T60', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Harold Varner III': [('T40', 1.0),
#   ('T53', 1.0),
#   ('T17', 1.0),
#   ('6', 1.0),
#   ('T5', 0.5),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T51', 1.0),
#   ('MC', 0.5),
#   ('T7', 1.5),
#   ('T55', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('78', 1.0),
#   ('T72', 1.0),
#   ('T60', 1.0),
#   ('T38', 1.0)],
#  'Alex Cejka': [('T56', 1.0),
#   ('MC', 1.0),
#   ('T65', 1.0),
#   ('T13', 0.5),
#   ('T33', 1.0),
#   ('T40', 1.0),
#   ('T66', 1.0),
#   ('MC', 1.0),
#   ('T27', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T40', 1.0),
#   ('WD', 1.0),
#   ('75', 1.0),
#   ('WD', 1.0)],
#  'Trey Mullinax': [('T56', 1.0),
#   ('T36', 1.0),
#   ('MC', 1.0),
#   ('T56', 0.5),
#   ('T67', 1.0),
#   ('MC', 2.0),
#   ('T6', 1.0),
#   ('MC', 1.0),
#   ('T58', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('T8', 1.0),
#   ('T47', 1.0)],
#  'Brandon Harkins': [('T60', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T30', 0.5),
#   ('T38', 1.0),
#   ('T37', 1.0),
#   ('MC', 1.0),
#   ('T66', 1.0),
#   ('T67', 1.5),
#   ('T63', 1.0),
#   ('MC', 1.0),
#   ('T60', 0.5),
#   ('T36', 1.0),
#   ('MC', 1.0),
#   ('T41', 1.0),
#   ('T15', 1.0),
#   ('MC', 1.0)],
#  'Sam Saunders': [('T60', 1.0),
#   ('T45', 1.0),
#   ('MC', 1.0),
#   ('T60', 1.0),
#   ('T5', 0.5),
#   ('T47', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T9', 1.0),
#   ('MC', 1.0),
#   ('T72', 0.5),
#   ('MC', 1.0),
#   ('T49', 1.0),
#   ('MC', 1.0),
#   ('T26', 1.0),
#   ('T26', 1.0)],
#  'Martin Laird': [('T73', 1.0),
#   ('T45', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T61', 1.0),
#   ('T23', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T57', 1.5),
#   ('T32', 1.0),
#   ('T26', 1.0),
#   ('MC', 1.0),
#   ('T9', 1.0),
#   ('T9', 1.0)],
#  'Sunghoon Kang': [('75', 1.0),
#   ('T53', 1.0),
#   ('MC', 1.0),
#   ('T67', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T57', 1.0),
#   ('MC', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('WD', 0.5),
#   ('T58', 1.0),
#   ('73', 1.0),
#   ('MC', 1.0),
#   ('T16', 1.0),
#   ('MC', 1.0)],
#  'Nick Taylor': [('MC', 1.0),
#   ('T8', 1.0),
#   ('T71', 1.0),
#   ('T34', 1.0),
#   ('T56', 0.5),
#   ('MC', 1.0),
#   ('T30', 1.0),
#   ('MC', 1.0),
#   ('T32', 1.0),
#   ('T79', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T41', 1.0),
#   ('MC', 1.0),
#   ('T52', 1.0)],
#  'Charl Schwartzel': [('MC', 1.0),
#   ('T42', 2.0),
#   ('T31', 1.0),
#   ('MC', 2.0),
#   ('MC', 2.0),
#   ('72', 1.0),
#   ('MC', 1.0),
#   ('T2', 1.5),
#   ('T9', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T36', 1.0),
#   ('MC', 1.0),
#   ('T49', 1.0),
#   ('T48', 1.5),
#   ('T68', 1.0)],
#  'John Huh': [('MC', 1.0),
#   ('MC', 1.0),
#   ('T50', 1.0),
#   ('T7', 1.0),
#   ('MC', 0.5),
#   ('T61', 1.0),
#   ('MC', 1.0),
#   ('T44', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('T23', 1.0),
#   ('T32', 0.5),
#   ('T26', 1.0),
#   ('MC', 1.0),
#   ('T24', 1.0),
#   ('T26', 1.0),
#   ('T38', 1.0)],
#  'Vaughn Taylor': [('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T34', 1.0),
#   ('MC', 0.5),
#   ('T47', 1.0),
#   ('T18', 1.0),
#   ('T20', 1.0),
#   ('T59', 1.0),
#   ('MC', 1.5),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('T59', 1.0),
#   ('T20', 1.0),
#   ('T55', 1.0),
#   ('T11', 1.0)],
#  'Scott Brown': [('MC', 1.0),
#   ('T57', 1.0),
#   ('80', 2.0),
#   ('MC', 1.0),
#   ('T12', 1.0),
#   ('T56', 0.5),
#   ('T47', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T23', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T76', 0.5),
#   ('MC', 1.0),
#   ('T64', 1.0),
#   ('T46', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Harris English': [('MC', 1.0),
#   ('T11', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T20', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('T32', 1.0),
#   ('MC', 0.5),
#   ('T22', 1.0),
#   ('MC', 1.0),
#   ('T33', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Rory Sabbatini': [('MC', 1.0),
#   ('T57', 1.0),
#   ('T12', 1.0),
#   ('WD', 1.0),
#   ('T39', 0.5),
#   ('MC', 1.0),
#   ('T44', 1.0),
#   ('T20', 1.0),
#   ('T13', 1.0),
#   ('T30', 1.5),
#   ('T27', 1.0),
#   ('T23', 1.0),
#   ('T70', 0.5),
#   ('T5', 1.0),
#   ('T17', 1.0),
#   ('72', 1.0),
#   ('T31', 1.0)],
#  'Ryan Blaum': [('MC', 1.0),
#   ('T57', 1.0),
#   ('T22', 1.0),
#   ('T55', 1.0),
#   ('MC', 0.5),
#   ('T12', 1.0),
#   ('T18', 1.0),
#   ('MC', 1.0),
#   ('T6', 1.0),
#   ('T77', 1.5),
#   ('T84', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('T16', 1.0),
#   ('MC', 1.0),
#   ('T60', 1.0),
#   ('T73', 1.0),
#   ('MC', 1.0)],
#  'Tyler Duncan(Jul1989)': [('MC', 1.0),
#   ('MC', 1.0),
#   ('T17', 1.0),
#   ('T12', 1.0),
#   ('T39', 0.5),
#   ('T33', 1.0),
#   ('T56', 2.0),
#   ('T37', 1.0),
#   ('T71', 1.0),
#   ('T26', 1.0),
#   ('T84', 1.0),
#   ('T52', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T24', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Richy Werenski': [('MC', 1.0),
#   ('T53', 1.0),
#   ('T23', 1.0),
#   ('T69', 0.5),
#   ('T26', 1.0),
#   ('MC', 2.0),
#   ('T4', 1.0),
#   ('T74', 1.0),
#   ('MC', 1.0),
#   ('T23', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T85', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'JT Poston': [('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T65', 1.0),
#   ('T39', 0.5),
#   ('MC', 1.0),
#   ('T18', 1.0),
#   ('T20', 1.0),
#   ('T26', 1.0),
#   ('MC', 1.0),
#   ('T68', 1.0)],
#  'William McGirt': [('MC', 1.0),
#   ('T57', 1.0),
#   ('T29', 1.0),
#   ('MC', 1.0),
#   ('T69', 0.5),
#   ('MC', 1.0),
#   ('T30', 1.0),
#   ('MC', 1.0),
#   ('T32', 1.0),
#   ('MC', 1.5),
#   ('T70', 1.0),
#   ('MC', 0.5),
#   ('T26', 1.0),
#   ('T16', 1.0),
#   ('T33', 1.0),
#   ('MC', 1.0),
#   ('T26', 1.0),
#   ('MC', 1.0)],
#  'Grayson Murray': [('WD', 1.0),
#   ('MC', 1.0),
#   ('T70', 1.0),
#   ('73', 1.0),
#   ('MC', 1.0),
#   ('WD', 1.0),
#   ('T30', 1.5),
#   ('T59', 1.0),
#   ('MC', 1.0),
#   ('T14', 0.5),
#   ('T14', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T8', 1.0),
#   ('T70', 1.0)],
#  'Jim Furyk': [('T4', 1.0),
#   ('T71', 2.0),
#   ('T45', 1.0),
#   ('T47', 0.5),
#   ('MC', 1.0),
#   ('T48', 2.0),
#   ('MC', 1.0),
#   ('T66', 1.0),
#   ('T70', 1.0),
#   ('7', 1.0),
#   ('T46', 1.0),
#   ('MC', 1.0)],
#  'D.A. Points': [('T4', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'David Hearn': [('T8', 1.0),
#   ('T61', 1.0),
#   ('T16', 1.0),
#   ('T30', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Michael Thompson': [('T11', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('T32', 1.0),
#   ('T59', 1.0),
#   ('MC', 1.5),
#   ('T42', 1.0),
#   ('T42', 1.0),
#   ('T14', 0.5),
#   ('T24', 1.0)],
#  'John Oda': [('T11', 1.0), ('MC', 1.0)],
#  'Brett Stegmaier': [('T11', 1.0),
#   ('MC', 1.0),
#   ('T65', 1.0),
#   ('T30', 0.5),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T43', 0.5),
#   ('MC', 1.0)],
#  'Doug Ghim': [('T20', 1.0),
#   ('WD', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T50', 2.0)],
#  'Shawn Stefani': [('T24', 1.0),
#   ('T22', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T66', 1.0),
#   ('T26', 1.0),
#   ('T42', 1.0),
#   ('T24', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Peter Malnati': [('T24', 1.0),
#   ('T61', 1.0),
#   ('MC', 1.0),
#   ('T56', 0.5),
#   ('T26', 1.0),
#   ('T30', 1.0),
#   ('T59', 1.0),
#   ('T34', 1.0),
#   ('T67', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T49', 1.0),
#   ('MC', 1.0),
#   ('T35', 1.0),
#   ('MC', 1.0)],
#  'Patrick Rodgers': [('T24', 1.0),
#   ('MC', 1.0),
#   ('T43', 1.0),
#   ('MC', 0.5),
#   ('T26', 1.0),
#   ('T41', 2.0),
#   ('T8', 1.0),
#   ('MC', 1.0),
#   ('T53', 1.0),
#   ('MC', 1.5),
#   ('T34', 1.0),
#   ('MC', 0.5),
#   ('T7', 1.0),
#   ('T59', 1.0),
#   ('T33', 1.0),
#   ('T26', 1.0),
#   ('T8', 1.0),
#   ('MC', 1.0)],
#  'Sergio Garcia': [('T24', 1.0),
#   ('MC', 2.0),
#   ('T39', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('70', 1.5),
#   ('MC', 2.0),
#   ('T9', 1.0),
#   ('4', 1.0),
#   ('T7', 1.5),
#   ('T33', 1.0)],
#  'Jonathan Byrd': [('T24', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('T50', 1.0),
#   ('T76', 0.5),
#   ('T62', 1.0)],
#  'Aaron Baddeley': [('T24', 1.0),
#   ('T65', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T25', 2.0),
#   ('T37', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T55', 1.0),
#   ('74', 0.5),
#   ('T49', 1.0),
#   ('T14', 1.0),
#   ('T55', 1.0),
#   ('T26', 1.0)],
#  'Cameron Percy': [('T33', 1.0),
#   ('T69', 1.0),
#   ('MC', 1.0),
#   ('T56', 0.5),
#   ('T26', 1.0),
#   ('T70', 1.0),
#   ('MC', 1.0)],
#  'Johnson Wagner': [('T33', 1.0),
#   ('T29', 1.0),
#   ('T16', 1.0),
#   ('T65', 0.5),
#   ('MC', 1.0),
#   ('T32', 1.0),
#   ('T13', 1.0),
#   ('T52', 0.5),
#   ('T55', 1.0)],
#  'Joaquin Niemann': [('T33', 1.0),
#   ('T71', 2.0),
#   ('T37', 1.0),
#   ('T23', 1.0),
#   ('T5', 0.5),
#   ('MC', 1.0),
#   ('T6', 1.0),
#   ('T8', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0)],
#  'Matthew Fitzpatrick': [('T36', 1.0),
#   ('MC', 2.0),
#   ('T48', 1.0),
#   ('MC', 2.0),
#   ('T14', 1.0),
#   ('MC', 1.0),
#   ('T12', 2.0),
#   ('T8', 0.5),
#   ('T46', 1.5),
#   ('T14', 1.0),
#   ('T38', 2.0),
#   ('T36', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T30', 1.5)],
#  'Jonas Blixt': [('T36', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('T27', 1.0),
#   ('T14', 1.0),
#   ('MC', 0.5),
#   ('T41', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Denny McCarthy': [('T36', 1.0),
#   ('T34', 1.0),
#   ('T39', 0.5),
#   ('T47', 1.0),
#   ('T18', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('T43', 0.5),
#   ('MC', 1.0),
#   ('T66', 1.0)],
#  'Dylan Meyer': [('T36', 1.0),
#   ('MC', 1.0),
#   ('T43', 1.0),
#   ('MC', 1.0),
#   ('T20', 2.0),
#   ('T74', 1.0)],
#  'Billy Hurley III': [('T41', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T47', 0.5),
#   ('T47', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('81', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Julian Suri': [('T41', 1.0),
#   ('T19', 2.0),
#   ('T28', 2.0),
#   ('MC', 1.0),
#   ('27', 1.0),
#   ('T29', 1.0),
#   ('T43', 0.5),
#   ('T8', 0.5),
#   ('T29', 1.0),
#   ('T68', 1.0),
#   ('MC', 1.0)],
#  'Blayne Barber': [('T41', 1.0),
#   ('MC', 1.0),
#   ('T43', 1.0),
#   ('T39', 0.5),
#   ('T26', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('T67', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('T16', 1.0),
#   ('MC', 1.0),
#   ('T67', 1.0)],
#  'Corey Conners': [('T45', 1.0),
#   ('MC', 1.0),
#   ('T50', 1.0),
#   ('T30', 0.5),
#   ('MC', 1.0),
#   ('68', 1.0),
#   ('T8', 1.0),
#   ('T53', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('T16', 1.0),
#   ('T59', 1.0),
#   ('MC', 1.0)],
#  'Sangmoon Bae': [('T45', 1.0),
#   ('WD', 1.0),
#   ('MC', 1.0),
#   ('69', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T75', 1.0),
#   ('T15', 1.0),
#   ('MC', 1.0)],
#  'Bill Haas': [('T45', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('T72', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T36', 2.0),
#   ('T57', 1.0),
#   ('T14', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('T7', 1.0),
#   ('T76', 0.5),
#   ('T49', 1.0),
#   ('T26', 1.0)],
#  'Roberto Diaz': [('T53', 1.0),
#   ('MC', 1.0),
#   ('WD', 1.0),
#   ('T47', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T66', 1.0),
#   ('MC', 1.0),
#   ('T32', 0.5),
#   ('T33', 1.0),
#   ('MC', 1.0)],
#  'Lanto Griffin': [('T57', 1.0),
#   ('T69', 1.0),
#   ('T60', 1.0),
#   ('T26', 0.5),
#   ('T38', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Graeme McDowell': [('T57', 1.0),
#   ('T17', 1.0),
#   ('63', 1.0),
#   ('T40', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T12', 0.5),
#   ('MC', 1.0),
#   ('T27', 1.0),
#   ('T55', 1.0),
#   ('T22', 1.0),
#   ('T40', 1.0),
#   ('MC', 1.0),
#   ('T26', 1.0),
#   ('MC', 1.0)],
#  'Martin Flores': [('65', 1.0),
#   ('T50', 1.0),
#   ('T72', 1.0),
#   ('MC', 0.5),
#   ('T72', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T26', 1.0),
#   ('MC', 1.5),
#   ('T59', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('77', 1.0),
#   ('T74', 1.0),
#   ('MC', 1.0),
#   ('T21', 1.0)],
#  'Hudson Swafford': [('T66', 1.0),
#   ('T12', 1.0),
#   ('T50', 1.0),
#   ('MC', 0.5),
#   ('T59', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T75', 1.0),
#   ('MC', 1.0),
#   ('T64', 1.0),
#   ('MC', 1.0)],
#  'Mackenzie Hughes': [('T66', 1.0),
#   ('T8', 1.0),
#   ('T16', 1.0),
#   ('T13', 0.5),
#   ('T42', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T42', 1.0),
#   ('T57', 1.5),
#   ('T59', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('T54', 1.0),
#   ('MC', 1.0),
#   ('T59', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Conrad Shindler': [('T66', 1.0),
#   ('MC', 1.0),
#   ('T55', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('65', 1.0),
#   ('T32', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Stephan Jaeger': [('T70', 1.0),
#   ('T71', 1.0),
#   ('MC', 1.0),
#   ('T47', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('T49', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T43', 1.0)],
#  'Zhang Xinjun': [('T70', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T70', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T43', 1.0)],
#  'Ricky Barnes': [('T70', 1.0),
#   ('T17', 1.0),
#   ('T43', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('DQ', 1.0),
#   ('T62', 1.0),
#   ('MC', 1.0)],
#  'Jason Bohn': [('MC', 1.0), ('T30', 1.0), ('MC', 1.0)],
#  'Arjun Atwal': [('MC', 1.0), ('T65', 1.0)],
#  'Ernie Els': [('MC', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T72', 0.5),
#   ('T49', 1.0),
#   ('T64', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Stuart Appleby': [('MC', 1.0),
#   ('T50', 1.0),
#   ('MC', 0.5),
#   ('T12', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Tyrone van Aswegen': [('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('77', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T14', 1.0),
#   ('MC', 1.0),
#   ('66', 1.5),
#   ('T82', 1.0),
#   ('T23', 1.0),
#   ('T32', 0.5),
#   ('72', 1.0),
#   ('T28', 1.0),
#   ('T68', 1.0),
#   ('T68', 1.0),
#   ('T26', 1.0),
#   ('69', 1.0)],
#  'Martin Piller': [('MC', 1.0),
#   ('T45', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T77', 1.0),
#   ('T21', 1.0),
#   ('MC', 1.0),
#   ('T24', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('67', 1.0),
#   ('67', 1.0),
#   ('MC', 1.0)],
#  'Shane Lowry': [('MC', 1.0),
#   ('T12', 2.0),
#   ('T12', 1.0),
#   ('MC', 2.0),
#   ('T28', 1.0),
#   ('MC', 2.0),
#   ('T30', 1.0),
#   ('T52', 1.0),
#   ('T15', 0.5),
#   ('T46', 1.5),
#   ('T34', 1.0),
#   ('T14', 0.5),
#   ('MC', 1.0),
#   ('T49', 1.0),
#   ('T49', 1.0),
#   ('MC', 1.0),
#   ('T43', 1.0),
#   ('T65', 1.0)],
#  'Nicholas Lindheim': [('MC', 1.0),
#   ('MC', 1.0),
#   ('T69', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T56', 1.0),
#   ('T32', 1.0),
#   ('T32', 1.0),
#   ('MC', 1.0),
#   ('T14', 0.5),
#   ('MC', 1.0),
#   ('WD', 1.0),
#   ('MC', 1.0)],
#  'T.J. Vogel': [('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T66', 1.0),
#   ('T59', 1.0),
#   ('T16', 1.0),
#   ('MC', 1.0)],
#  'Marty Dou Zecheng': [('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T56', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T55', 1.0)],
#  'Will Zalatoris': [('MC', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T68', 1.0)],
#  'Michael DeMorat': [('MC', 1.0), ('T56', 2.0)],
#  'Norman Xiong': [('MC', 1.0), ('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Ben Crane': [('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T8', 1.0),
#   ('T53', 1.0),
#   ('T43', 0.5),
#   ('T74', 1.0),
#   ('MC', 1.0)],
#  'Davis Love III': [('MC', 1.0),
#   ('MC', 2.0),
#   ('MC', 1.0),
#   ('WD', 1.0),
#   ('T74', 1.0),
#   ('T58', 1.0),
#   ('MC', 1.0)],
#  'Steve Stricker': [('MC', 1.0),
#   ('T50', 1.0),
#   ('T43', 1.0),
#   ('T20', 2.0),
#   ('T18', 1.0),
#   ('T32', 1.0),
#   ('T23', 1.5),
#   ('MC', 0.5),
#   ('T12', 1.0),
#   ('T26', 1.0),
#   ('T31', 1.0)],
#  'David Lingmerth': [('MC', 1.0),
#   ('T50', 1.0),
#   ('T72', 1.0),
#   ('T11', 0.5),
#   ('T19', 1.0),
#   ('MC', 1.0),
#   ('T29', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('T74', 1.0),
#   ('T64', 1.0),
#   ('T64', 1.0),
#   ('MC', 1.0),
#   ('T75', 1.0)],
#  'Andrew Yun': [('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Talor Gooch': [('MC', 1.0),
#   ('MC', 1.0),
#   ('WD', 1.0),
#   ('T21', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T13', 1.0),
#   ('MC', 0.5),
#   ('T26', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T20', 1.0),
#   ('MC', 1.0)],
#  'Dominic Bozzelli': [('MC', 1.0),
#   ('T65', 1.0),
#   ('T23', 1.0),
#   ('MC', 0.5),
#   ('T72', 1.0),
#   ('T51', 1.0),
#   ('T59', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('T40', 1.0),
#   ('90', 0.5),
#   ('T31', 1.0),
#   ('T13', 1.0),
#   ('T26', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Fabian Gomez': [('MC', 1.0),
#   ('MC', 1.0),
#   ('T23', 1.0),
#   ('T56', 0.5),
#   ('T19', 1.0),
#   ('T45', 1.0),
#   ('T32', 1.0),
#   ('T84', 1.0),
#   ('T50', 1.0),
#   ('T85', 0.5),
#   ('T68', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Matt Jones': [('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 2.0),
#   ('T12', 1.0),
#   ('MC', 0.5),
#   ('T19', 1.0),
#   ('MC', 2.0),
#   ('T51', 1.0),
#   ('T13', 1.0),
#   ('T52', 0.5),
#   ('MC', 1.0)],
#  'Zac Blair': [('MC', 1.0),
#   ('T50', 1.0),
#   ('MC', 1.0),
#   ('T65', 0.5),
#   ('T45', 1.0),
#   ('T42', 1.0),
#   ('MC', 1.0)],
#  'Benjamin Silverman': [('MC', 1.0),
#   ('T71', 1.0),
#   ('T65', 1.0),
#   ('T56', 0.5),
#   ('MC', 1.0),
#   ('67', 1.0),
#   ('T11', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T80', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T53', 1.0),
#   ('MC', 1.0),
#   ('T48', 1.0)],
#  'Cody Gribble': [('MC', 1.0),
#   ('T34', 1.0),
#   ('MC', 0.5),
#   ('T30', 1.0),
#   ('MC', 1.0),
#   ('T32', 1.0),
#   ('T30', 1.5),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T70', 1.0)],
#  'Robert Garrigus': [('MC', 1.0),
#   ('T22', 1.0),
#   ('T30', 1.0),
#   ('MC', 0.5),
# ...
#  'Lee Westwood': [('T61', 2.0),
#   ('T32', 1.0),
#   ('T19', 1.0),
#   ('T27', 0.5),
#   ('T80', 0.5)],
#  'Gavin Green': [('T61', 2.0),
#   ('T19', 1.0),
#   ('MC', 1.0),
#   ('T52', 0.5),
#   ('64', 1.5)],
#  'Marcus Kinhult': [('T61', 2.0), ('MC', 1.0), ('T12', 0.5)],
#  'Matthew Southgate': [('T67', 2.0),
#   ('T23', 1.0),
#   ('T59', 1.0),
#   ('MC', 2.0),
#   ('T27', 0.5)],
#  'Zander Lombard': [('T67', 2.0), ('MC', 1.0), ('T6', 1.0), ('MC', 0.5)],
#  'Rhys Enoch': [('T67', 2.0)],
#  'Sam Locke': [('T75', 2.0)],
#  'Fabrizio Zanotti': [('MC', 2.0), ('MC', 1.0), ('MC', 1.0), ('T15', 0.5)],
#  'George Coetzee': [('MC', 2.0), ('MC', 1.0), ('T24', 1.0), ('MC', 0.5)],
#  'Tom Lehman': [('MC', 2.0)],
#  'Oliver Wilson': [('MC', 2.0)],
#  'Nicolai Hojgaard(Am)': [('MC', 2.0)],
#  'Marcus Armitage': [('MC', 2.0)],
#  'Scott Jamieson': [('MC', 2.0), ('MC', 1.0), ('T40', 1.0), ('MC', 0.5)],
#  'Mark Calcavecchia': [('MC', 2.0)],
#  'Sanghyun Park': [('MC', 2.0)],
#  'Jazz Janewattananond': [('MC', 2.0)],
#  'Thomas Curtis': [('MC', 2.0)],
#  'Haraldur Magnus': [('MC', 2.0)],
#  'Hideto Tanihara': [('MC', 2.0), ('T58', 1.0), ('MC', 1.0), ('T35', 0.5)],
#  'Shota Akiyoshi': [('MC', 2.0), ('MC', 2.0)],
#  'Michael Hendry': [('MC', 2.0)],
#  'Sandy Lyle': [('MC', 2.0), ('MC', 2.0)],
#  'Todd Hamilton': [('MC', 2.0)],
#  'Danthai Boonma': [('MC', 2.0)],
#  'Minchel Choi': [('MC', 2.0)],
#  'Grant Forrest': [('MC', 2.0)],
#  'Nicolas Colsaerts': [('MC', 2.0), ('T42', 1.0), ('T19', 1.0), ('MC', 0.5)],
#  'Lin YuxinAm)': [('MC', 2.0), ('MC', 2.0)],
#  'Brady Schnell': [('MC', 2.0)],
#  'Masanori Kobayashi': [('MC', 2.0)],
#  'Jack Senior': [('MC', 2.0)],
#  'Ashton Turner': [('MC', 2.0)],
#  'James Robinson': [('MC', 2.0)],
#  'Jens Dantorp': [('MC', 2.0), ('T3', 1.0), ('76', 1.0), ('T35', 0.5)],
#  'Jovan Rebula(Am)': [('MC', 2.0)],
#  'Darren Clarke': [('MC', 2.0), ('MC', 1.0), ('MC', 1.0)],
#  'David Duval': [('WD', 2.0), ('MC', 1.0), ('MC', 1.0)],
#  'Trevor Immelman': [('T3', 1.0), ('DQ', 1.0), ('T58', 0.5), ('MC', 2.0)],
#  'Dean Burmester': [('T9', 1.0),
#   ('T28', 1.0),
#   ('T56', 2.0),
#   ('T12', 0.5),
#   ('T30', 1.5)],
#  'Aaron Rai': [('T9', 1.0), ('T37', 1.0), ('MC', 0.5)],
#  'Stephen Gallacher': [('T9', 1.0), ('MC', 1.0), ('T52', 0.5)],
#  'Marcel Siem': [('T14', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Richard Sterne': [('T14', 1.0), ('T37', 1.0), ('MC', 0.5)],
#  'Scott Hend': [('T14', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Andrea Pavan': [('T14', 1.0), ('MC', 1.0), ('T52', 0.5)],
#  'Sam Horsfield': [('T23', 1.0), ('T24', 1.0), ('T15', 0.5), ('T14', 1.0)],
#  'Justin Walters': [('T23', 1.0), ('MC', 1.0)],
#  'Joakim Lagergren': [('T23', 1.0), ('T12', 1.0), ('MC', 0.5)],
#  'Rakhyun Cho': [('T30', 1.0), ('MC', 1.0), ('T64', 0.5)],
#  'Connor Syme': [('T32', 1.0), ('MC', 1.0)],
#  'Thongchai Jaidee': [('T32', 1.0), ('T49', 1.0), ('T8', 0.5)],
#  'Gonzalo Fdez-Castano': [('T32', 1.0), ('T37', 1.0), ('MC', 0.5)],
#  'James Morrison': [('T32', 1.0), ('T49', 1.0), ('MC', 2.0), ('MC', 0.5)],
#  'Steven Brown': [('T32', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Ricardo Gouveia': [('T32', 1.0), ('T64', 1.0), ('MC', 0.5)],
#  'Oliver Fisher': [('T32', 1.0), ('T28', 1.0), ('MC', 0.5)],
#  'Christiaan Bezuidenhout': [('T42', 1.0), ('T19', 1.0)],
#  'Darren Fichardt': [('T42', 1.0), ('T40', 1.0), ('7', 0.5)],
#  'Soren Kjeldsen': [('T42', 1.0), ('T59', 1.0), ('MC', 0.5)],
#  'Matthieu Pavon': [('T42', 1.0), ('T10', 1.0), ('T25', 2.0), ('T64', 0.5)],
#  'Jinho Choi': [('T49', 1.0), ('T64', 1.0), ('MC', 0.5)],
#  'Robert Karlsson': [('T49', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Robert Rock': [('T49', 1.0), ('T28', 1.0), ('T20', 0.5)],
#  'Benjamin Hebert': [('T49', 1.0), ('T28', 1.0), ('T35', 0.5)],
#  'Oliver Farr': [('T49', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Lorenzo Gagli': [('T55', 1.0), ('MC', 1.0)],
#  'Julien Guerrier': [('T55', 1.0), ('T64', 1.0), ('MC', 0.5)],
#  'Jamie McLeary': [('T58', 1.0)],
#  'Clement Sordet': [('T58', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Scott Fernandez': [('T58', 1.0), ('MC', 1.0), ('T43', 0.5)],
#  'Duncan Stewart': [('T58', 1.0)],
#  'Pedro Oriol': [('T64', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Thomas Detry': [('T64', 1.0), ('MC', 1.0), ('T43', 0.5)],
#  'Adam Bland': [('66', 1.0), ('T49', 1.0), ('MC', 0.5), ('T18', 1.5)],
#  'Lasse Jensen': [('MC', 1.0), ('MC', 1.0), ('T27', 0.5)],
#  'David Horsey': [('MC', 1.0), ('T40', 1.0), ('MC', 0.5)],
#  'Matteo Manassero': [('MC', 1.0), ('T64', 1.0), ('T27', 0.5)],
#  'Lucas Bjerregaard': [('MC', 1.0), ('MC', 1.0), ('T3', 0.5)],
#  'Edoardo Molinari': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Bradley Dredge': [('MC', 1.0), ('T69', 1.0), ('MC', 0.5)],
#  'Peter Hanson': [('MC', 1.0), ('T49', 1.0), ('MC', 0.5)],
#  'Soomin Lee': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Nacho Elvira': [('MC', 1.0), ('T49', 1.0), ('MC', 0.5)],
#  'Jeff Winther': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Chris Paisley': [('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T37', 1.5)],
#  'Jacques Kruyswijk': [('MC', 1.0), ('MC', 1.0), ('T20', 0.5)],
#  'Richie Ramsay': [('MC', 1.0), ('T40', 1.0), ('MC', 2.0), ('T35', 0.5)],
#  'Wu Ashun': [('MC', 1.0), ('DQ', 1.0), ('T64', 0.5)],
#  'Charlie Ford': [('MC', 1.0), ('75', 1.0), ('MC', 0.5)],
#  'Laurie Canter': [('MC', 1.0), ('MC', 1.0)],
#  'Jason Scrivener': [('MC', 1.0), ('MC', 1.0), ('MC', 2.0), ('MC', 0.5)],
#  'Tapio Pulkkanen': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Chris Hanson': [('MC', 1.0), ('WD', 1.0), ('MC', 0.5)],
#  'Bradley Neil': [('MC', 1.0), ('MC', 1.0), ('T58', 0.5)],
#  'Haydn Porteous': [('MC', 1.0), ('T49', 1.0), ('T43', 0.5)],
#  'Marc Warren': [('MC', 1.0), ('T49', 1.0), ('T60', 0.5)],
#  'Peter Whiteford': [('MC', 1.0)],
#  'Andrew Dodt': [('MC', 1.0), ('T72', 1.0), ('51', 0.5)],
#  'Raphael Jacquelin': [('MC', 1.0), ('T10', 1.0), ('MC', 0.5)],
#  'David Howell': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Gregory Havret': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Richard Bland': [('MC', 1.0), ('MC', 1.0), ('T35', 0.5)],
#  'Lee Slattery': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'David Drysdale': [('MC', 1.0), ('T28', 1.0), ('MC', 0.5)],
#  'Daniel Im': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Ashley Chesters': [('MC', 1.0), ('T14', 1.0), ('MC', 0.5)],
#  'Jeunghun Wang': [('MC', 1.0), ('T49', 1.0), ('T52', 0.5)],
#  'Chase Koepka': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Alvaro Quiros': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'S.S.P. Chawrasia': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Adrien Saddier': [('MC', 1.0), ('T19', 1.0), ('T35', 0.5)],
#  'Nino Bertasio': [('MC', 1.0), ('MC', 1.0), ('T60', 0.5)],
#  'Ryan Evans': [('MC', 1.0), ('MC', 1.0), ('MC', 2.0), ('MC', 0.5)],
#  'Matthias Schwab': [('MC', 1.0), ('MC', 1.0)],
#  'Sebastien Gros': [('MC', 1.0), ('MC', 1.0), ('T27', 0.5)],
#  'Thomas Bjorn': [('MC', 1.0), ('T59', 1.0), ('MC', 0.5)],
#  'Matthew Baldwin': [('MC', 1.0), ('MC', 1.0)],
#  'Daniel Brooks': [('MC', 1.0), ('T59', 1.0), ('67', 0.5)],
#  'Paul Waring': [('MC', 1.0), ('T72', 1.0), ('MC', 2.0), ('T52', 0.5)],
#  'Romain Wattel': [('MC', 1.0), ('T28', 1.0), ('MC', 0.5)],
#  'Callum Shinkwin': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Renato Paratore': [('MC', 1.0), ('T40', 1.0), ('MC', 0.5)],
#  'Gregory Bourdy': [('MC', 1.0), ('T64', 1.0), ('MC', 0.5)],
#  'Mikko Ilonen': [('MC', 1.0), ('T19', 1.0), ('MC', 0.5)],
#  'Thomas Aiken': [('MC', 1.0), ('T40', 1.0), ('MC', 0.5)],
#  'Sam Brazel': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Jamie Donaldson': [('MC', 1.0), ('MC', 0.5)],
#  'Pablo Larrazabal': [('MC', 1.0), ('T49', 1.0), ('MC', 0.5)],
#  'Carlos Pigem': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  "Conor O'Neil": [('MC', 1.0)],
#  'David Lipsky': [('MC', 1.0), ('MC', 1.0), ('T27', 0.5), ('T48', 1.5)],
#  'Jason Norris': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Maximilian Kieffer': [('MC', 1.0), ('MC', 1.0), ('42', 0.5)],
#  'Phachara Khongwatmai': [('MC', 1.0), ('MC', 1.0), ('MC', 0.5)],
#  'Nick Hardy(am)': [('T43', 1.0), ('T61', 1.0)],
#  'Mark Wilson': [('T63', 1.0), ('MC', 1.0), ('74', 1.0)],
#  'D.J. Trahan': [('80', 1.0), ('MC', 1.0), ('MC', 1.0)],
#  'Tim Herron': [('MC', 1.0),
#   ('MC', 0.5),
#   ('T37', 1.0),
#   ('T11', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Manav Shah': [('MC', 1.0)],
#  'Charlie Wi': [('MC', 1.0)],
#  'Dru Love IV': [('MC', 1.0), ('MC', 1.0), ('MC', 1.0)],
#  'Broc Everett': [('MC', 1.0)],
#  'Charlie Beljan': [('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('72', 1.0)],
#  'Vince India': [('MC', 1.0)],
#  'Steven Bowditch': [('MC', 1.0), ('MC', 0.5), ('MC', 1.0)],
#  'Troy Matteson': [('MC', 1.0), ('MC', 0.5), ('MC', 1.0), ('MC', 1.0)],
#  'Robert Allenby': [('MC', 1.0), ('MC', 0.5), ('MC', 1.0), ('75', 1.0)],
#  'Daniel Chopra': [('MC', 1.0), ('MC', 1.0), ('MC', 1.0)],
#  'Chris Couch': [('MC', 1.0), ('MC', 0.5), ('WD', 1.0), ('T68', 1.0)],
#  'John Rollins': [('MC', 1.0), ('MC', 1.0), ('MC', 1.0)],
#  'Brian Bullington': [('MC', 1.0)],
#  'Brendon Todd': [('MC', 1.0), ('MC', 1.0)],
#  'Craig Barlow': [('MC', 1.0)],
#  'Chad Proehl': [('MC', 1.0)],
#  'David Berganio-Jr': [('DQ', 1.0), ('MC', 1.0), ('MC', 1.0)],
#  'Jason Gore': [('WD', 1.0), ('MC', 0.5)],
#  'Cameron Beckman': [('WD', 1.0), ('MC', 1.0), ('MC', 1.0)],
#  'Matthew Nixon': [('T24', 1.0)],
#  'Simon Thornton': [('T59', 1.0)],
#  'Felipe Aguilar': [('T69', 1.0)],
#  'Gavin Moynihan': [('MC', 1.0)],
#  'Ruaidhri McGee': [('MC', 1.0)],
#  'Cormac Sharvin': [('MC', 1.0)],
#  'Mark Foster': [('MC', 1.0)],
#  'Paul McGinley': [('MC', 1.0)],
#  'Colm Moriarty': [('MC', 1.0)],
#  'Nicolas Geyger': [('MC', 1.0)],
#  'Christofer Blomstrand': [('MC', 1.0)],
#  'Cian McNamara': [('MC', 1.0)],
#  "Neil O'Briain": [('MC', 1.0)],
#  'Marcus Fraser': [('WD', 1.0), ('MC', 0.5)],
#  'Henric Sturehed': [('WD', 1.0)],
#  'John Peterson': [('T13', 0.5), ('T45', 1.0), ('T42', 1.0), ('T57', 1.0)],
#  'Steve Marino': [('T69', 0.5),
#   ('T26', 1.0),
#   ('MC', 1.0),
#   ('WD', 1.0),
#   ('MC', 1.0)],
#  'Chase Seiffert': [('MC', 0.5), ('T9', 1.0)],
#  'Wes Homan': [('MC', 0.5)],
#  'David S Bradshaw': [('MC', 0.5)],
#  'Bob Estes': [('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('WD', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('T49', 1.0),
#   ('MC', 1.0)],
#  'Blake Taylor': [('MC', 0.5)],
#  'Logan Lagodich': [('MC', 0.5)],
#  'Davey Jude': [('MC', 0.5)],
#  'Jon Curran': [('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  "Sam O'Dell": [('MC', 0.5)],
#  'Geoff Ogilvy': [('MC', 0.5),
#   ('MC', 1.0),
#   ('T32', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Devin Gee': [('MC', 0.5)],
#  'Smylie Kaufman': [('WD', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Ben Martin': [('MC', 1.0),
#   ('MC', 1.0),
#   ('T32', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.5),
#   ('MC', 1.0),
#   ('T55', 1.0),
#   ('MC', 1.0),
#   ('T46', 1.0),
#   ('T33', 1.0),
#   ('T26', 1.0),
#   ('T67', 1.0)],
#  'Andrew Svoboda': [('MC', 1.0)],
#  'Rick Lamb': [('MC', 1.0), ('MC', 1.0), ('MC', 1.0), ('MC', 1.0)],
#  "Adam D'Amario": [('MC', 1.0)],
#  'Sam Burns': [('T41', 2.0),
#   ('81', 1.0),
#   ('MC', 1.0),
#   ('T55', 1.0),
#   ('T49', 1.0),
#   ('T12', 1.0),
#   ('T8', 1.0)],
#  'Tim Wilkinson': [('T48', 2.0)],
#  'Matt Parziale': [('T48', 2.0), ('MC', 2.0)],
#  'Luis Gagne': [('T48', 2.0)],
#  'Chris Naegel': [('T56', 2.0)],
#  'Calum Hill(Nov1994)': [('61', 2.0)],
#  'Andrew Johnston': [('62', 2.0), ('MC', 0.5)],
#  'Cameron Wilson': [('64', 2.0)],
#  'Will Grimmer': [('66', 2.0)],
#  'Braden Thornberry': [('MC', 2.0), ('T26', 1.0)],
#  'Roberto Castro': [('MC', 2.0)],
#  'Lucas Glover': [('MC', 2.0),
#   ('T52', 1.0),
#   ('T72', 1.5),
#   ('MC', 1.0),
#   ('T32', 1.0),
#   ('T32', 0.5),
#   ('T49', 1.0),
#   ('T74', 1.0),
#   ('T17', 1.0),
#   ('MC', 1.0),
#   ('T43', 1.0)],
#  'Eric Axley': [('MC', 2.0), ('MC', 1.0), ('T42', 1.0), ('T47', 1.0)],
#  'Sebastian Vazquez': [('MC', 2.0)],
#  'Ty Strafaci': [('MC', 2.0), ('MC', 1.0)],
#  'Juan Sebastian Munoz': [('MC', 2.0)],
#  'Cole Miller': [('MC', 2.0)],
#  'Sungjoon Park': [('MC', 2.0)],
#  'David Bransdon': [('MC', 2.0)],
#  'Chris Babcock': [('MC', 2.0)],
#  'Michael Putnam': [('MC', 2.0)],
#  'Rhett Rasmussen': [('MC', 2.0)],
#  'Michael Miller(1992)': [('MC', 2.0)],
#  'Stewart Hagestad(Am)': [('MC', 2.0)],
#  'Liang Wenchong': [('MC', 2.0)],
#  'Jacob Bergeron': [('MC', 2.0)],
#  'Theo Humphrey(Am)': [('MC', 2.0)],
#  'Yu Chun-an(am)': [('MC', 2.0)],
#  'David Gazzolo': [('MC', 2.0)],
#  'Rikuya Hoshino': [('MC', 2.0)],
#  'Kristoffer Reitan': [('MC', 2.0)],
#  'Kenny Perry': [('MC', 2.0), ('MC', 1.0)],
#  'Garrett Rank': [('MC', 2.0)],
#  'Franklin Huang(Am)': [('MC', 2.0)],
#  'Ryan Lumsden(Am)': [('MC', 2.0)],
#  'Timothy Wiseman': [('MC', 2.0)],
#  'Noah Goodwin': [('MC', 2.0), ('MC', 1.0)],
#  'Shintaro Ban(Am)': [('MC', 2.0)],
#  'Harry Ellis': [('MC', 2.0), ('MC', 1.0), ('MC', 2.0)],
#  'Sulman Raza': [('MC', 2.0)],
#  'Michael Hebert': [('MC', 2.0)],
#  'Philip Barbaree': [('MC', 2.0)],
#  'Scott Gregory': [('MC', 2.0)],
#  'Nate Lashley': [('T37', 1.0),
#   ('T32', 1.0),
#   ('MC', 1.0),
#   ('T18', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Scottie Scheffler(Am)': [('T43', 1.0), ('MC', 1.0)],
#  'A.J. McInerney': [('T63', 1.0), ('MC', 1.0)],
#  'Grant Hirschman': [('T63', 1.0)],
#  'Casey Wittenberg': [('69', 1.0)],
#  'Ben Crancer': [('MC', 1.0)],
#  'Zachary Olsen': [('MC', 1.0)],
#  'Dawson Armstrong': [('MC', 1.0)],
#  'Greg Chalmers': [('MC', 1.0),
#   ('MC', 1.0),
#   ('T21', 1.0),
#   ('MC', 1.0),
#   ('T70', 0.5),
#   ('MC', 1.0),
#   ('T17', 1.0),
#   ('T68', 1.0),
#   ('MC', 1.0),
#   ('MC', 1.0)],
#  'Andrew Dorn': [('T62', 1.0)],
#  'Bud Cauley': [('MC', 1.0),
#   ('MC', 1.5),
#   ('T67', 1.0),
#   ('T23', 1.0),
#   ('T18', 0.5),
#   ('T14', 1.0),
#   ('MC', 1.0),
#   ('WD', 1.0),
#   ('T20', 1.0),
#   ('MC', 1.0)],
#  'K.J. Choi': [('MC', 1.0),
#   ('T55', 1.0),
#   ('MC', 0.5),
#   ('MC', 1.0),
#   ('T26', 1.0),
#   ('MC', 1.0)],
#  'Maverick McNealy': [('T42', 1.0), ('T42', 1.0), ('MC', 1.0)],
#  'Keith Clearwater': [('MC', 1.0)],
#  'James Heath': [('68', 0.5)],
#  'Joost Luiten': [('MC', 0.5), ('T37', 1.5)],
#  "Paul O'Hara": [('MC', 0.5)],
#  'Robert Coles': [('MC', 0.5)],
#  'Richard Wallis': [('MC', 0.5)],
#  'Gavin Hay': [('MC', 0.5)],
#  'Oliver Goss': [('MC', 1.0)],
#  'Angel Cabrera': [('MC', 1.0), ('MC', 2.0), ('WD', 1.0)],
#  'Steven Ihm': [('MC', 1.0)],
#  'Ryan Baca': [('MC', 1.0), ('MC', 0.5)],
#  'Tom Whitney': [('MC', 1.0)],
#  'Brian Norman': [('MC', 1.0)],
#  'Scott McCarron': [('MC', 1.5)],
#  'Derek Ernst': [('MC', 1.0), ('MC', 1.0)],
#  'Ryan Ruffels': [('MC', 1.0)],
#  'Carter Jenkins': [('MC', 1.0)],
#  'J.T. Griffin': [('MC', 1.0)],
#  'Guillermo Pereira': [('MC', 1.0)],
#  'Luke Donald': [('MC', 1.0),
#   ('MC', 1.0),
#   ('T64', 1.0),
#   ('MC', 1.0),
#   ('T37', 1.0),
#   ('MC', 1.0)],
#  'Philip Knowles': [('MC', 1.0)],
#  'Colt Knost': [('MC', 1.0), ('MC', 1.0), ('MC', 1.0), ('T62', 1.0)],
#  'Glen Day': [('MC', 1.0)],
#  'Jeff Maggert': [('MC', 1.0)],
#  'Steve Scott': [('MC', 1.0)],
#  'Bernd Wiesberger': [('T24', 2.0), ('T29', 1.0), ('T30', 1.5), ('MC', 1.0)],
#  'Fred Couples': [('T38', 2.0)],
#  'Jose M Olazabal': [('MC', 2.0)],
#  'Ian Woosnam': [('MC', 2.0)],
#  'Larry Mize': [('MC', 2.0)],
#  "Mark O'Meara": [('MC', 2.0)],
#  'Bobby Gates': [('T52', 0.5)],
#  'Dawie van der Walt': [('T68', 0.5)],
#  'Andrew Loupe': [('MC', 0.5), ('MC', 1.0), ('MC', 1.0)],
#  'Zach Cabra': [('MC', 0.5)],
#  'Camilo Villegas': [('MC', 0.5),
#   ('MC', 1.0),
#   ('MC', 1.0),
#   ('T68', 1.0),
#   ('MC', 1.0),
#   ('T57', 1.0)],
#  'JJ Wood': [('MC', 0.5)],
#  'Curtis Luck': [('T58', 1.0)],
#  'Collin Morikawa(Am)': [('T64', 1.0)],
#  'Paul Goydos': [('T69', 1.0)],
#  'Robert Gamez': [('MC', 1.0)],
#  'Donny Lee': [('MC', 1.0)],
#  'Jimmy Stanger': [('MC', 1.0)],
#  'Jack Maguire': [('MC', 1.0)],
#  'Rod Perry': [('MC', 1.0)],
#  'Morgan Hoffmann': [('T49', 1.0), ('WD', 1.0), ('MC', 1.0)],
#  'Andrew Novak': [('T57', 1.0)],
#  'Jhared Hack': [('MC', 1.0)],
#  'Andrew Filbert': [('MC', 1.0)],
#  'Richard H. Lee': [('MC', 1.0), ('MC', 1.0)],
#  'Seunghyuk Kim': [('MC', 1.0)],
#  'Vinnie Poncino': [('MC', 1.0)],
#  'Jim Herman': [('WD', 1.0), ('MC', 1.0)],
#  'Jerry Kelly': [('MC', 1.0)],
#  'Peter Jacobsen': [('MC', 1.0)],
#  'David Solomon': [('MC', 1.0)],
#  'Wyndham Clark': [('MC', 1.0)],
#  'Jesse Mueller': [('MC', 1.0)]}

# %%
{player_id_to_name[k]: [( get_bucket_from_standing(el[0]), el[1]) for el in v] for k,v in  player_id_to_standings.items()}
# Out:
# {'Tiger Woods': [('1', 1.5),
#   ('4-10', 1.5),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('2-3', 2.0),
#   ('CM', 1.0),
#   ('4-10', 2.0),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('2-3', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Billy Horschel': [('2-3', 1.5),
#   ('2-3', 1.5),
#   ('boo', 0.5),
#   ('2-3', 1.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('4-10', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Dustin Johnson': [('2-3', 1.5),
#   ('11-25', 1.5),
#   ('4-10', 0.5),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('2-3', 1.0),
#   ('1', 1.0),
#   ('boo', 2.0),
#   ('2-3', 2.0),
#   ('1', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 1.5),
#   ('11-25', 1.0),
#   ('4-10', 2.0),
#   ('CM', 1.0),
#   ('4-10', 1.5),
#   ('11-25', 1.0),
#   ('2-3', 1.0)],
#  'Webb Simpson': [('4-10', 1.5),
#   ('4-10', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('2-3', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('4-10', 2.0),
#   ('boo', 1.0),
#   ('1', 1.5),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.5),
#   ('4-10', 1.0),
#   ('boo', 1.0)],
#  'Justin Rose': [('4-10', 1.5),
#   ('2-3', 1.5),
#   ('2-3', 0.5),
#   ('boo', 1.0),
#   ('11-25', 2.0),
#   ('2-3', 2.0),
#   ('4-10', 1.0),
#   ('4-10', 2.0),
#   ('4-10', 1.0),
#   ('1', 1.0),
#   ('11-25', 1.5),
#   ('11-25', 2.0),
#   ('CM', 0.5),
#   ('2-3', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.5)],
#  'Hideki Matsuyama': [('4-10', 1.5),
#   ('11-25', 1.5),
#   ('4-10', 0.5),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Rickie Fowler': [('4-10', 1.5),
#   ('4-10', 1.5),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('11-25', 2.0),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.5),
#   ('11-25', 1.0),
#   ('2-3', 2.0),
#   ('CM', 0.5),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('11-25', 1.0)],
#  'Justin Thomas': [('4-10', 1.5),
#   ('11-25', 1.5),
#   ('11-25', 0.5),
#   ('4-10', 1.0),
#   ('4-10', 2.0),
#   ('1', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('4-10', 1.0),
#   ('11-25', 1.5),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('4-10', 1.0),
#   ('2-3', 1.5),
#   ('1', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 1.0)],
#  'Xander Schauffele': [('4-10', 1.5),
#   ('2-3', 1.5),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('2-3', 2.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('4-10', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('2-3', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 1.5),
#   ('4-10', 1.0),
#   ('11-25', 1.0)],
#  'Rory McIlroy': [('4-10', 1.5),
#   ('4-10', 1.5),
#   ('11-25', 0.5),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('2-3', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('2-3', 0.5),
#   ('boo', 1.5),
#   ('11-25', 1.0),
#   ('4-10', 2.0),
#   ('CM', 1.0),
#   ('1', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Tommy Fleetwood': [('11-25', 1.5),
#   ('4-10', 1.5),
#   ('11-25', 0.5),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 2.0),
#   ('2-3', 2.0),
#   ('11-25', 0.5),
#   ('4-10', 1.5),
#   ('boo', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.5),
#   ('4-10', 1.0),
#   ('CM', 1.0)],
#  'Gary Woodland': [('11-25', 1.5),
#   ('11-25', 1.5),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('4-10', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('CM', 2.0),
#   ('11-25', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('1', 1.0)],
#  'Paul Casey': [('11-25', 1.5),
#   ('boo', 1.5),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('2-3', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 0.5),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('1', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0),
#   ('4-10', 1.0)],
#  'Jon Rahm': [('11-25', 1.5),
#   ('11-25', 1.5),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('4-10', 2.0),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('CM', 1.5),
#   ('4-10', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0)],
#  'Aaron Wise': [('11-25', 1.5),
#   ('11-25', 1.5),
#   ('CM', 0.5),
#   ('4-10', 1.0),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('1', 1.0),
#   ('2-3', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0)],
#  'Tony Finau': [('11-25', 1.5),
#   ('4-10', 1.5),
#   ('4-10', 0.5),
#   ('2-3', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('4-10', 2.0),
#   ('11-25', 0.5),
#   ('4-10', 2.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('11-25', 1.0),
#   ('4-10', 2.0),
#   ('11-25', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('2-3', 1.0),
#   ('boo', 1.0)],
#  'Kyle Stanley': [('11-25', 1.5),
#   ('CM', 1.5),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('2-3', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('2-3', 1.0),
#   ('boo', 1.5),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Jason Day': [('11-25', 1.5),
#   ('11-25', 1.5),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('4-10', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('4-10', 1.5),
#   ('1', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('2-3', 1.0)],
#  'Bryson DeChambeau': [('11-25', 1.5),
#   ('11-25', 1.5),
#   ('1', 0.5),
#   ('1', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 2.0),
#   ('1', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('4-10', 1.0),
#   ('2-3', 1.0),
#   ('CM', 2.0),
#   ('2-3', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0)],
#  'Cameron Smith': [('11-25', 1.5),
#   ('CM', 1.5),
#   ('2-3', 0.5),
#   ('2-3', 1.0),
#   ('CM', 2.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('4-10', 2.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0)],
#  'Patton Kizzire': [('11-25', 1.5),
#   ('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Patrick Cantlay': [('11-25', 1.5),
#   ('CM', 1.5),
#   ('11-25', 0.5),
#   ('4-10', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.5),
#   ('4-10', 1.0),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('4-10', 1.0),
#   ('CM', 1.0)],
#  'Marc Leishman': [('11-25', 1.5),
#   ('CM', 1.5),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('2-3', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('4-10', 2.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Francesco Molinari': [('11-25', 1.5),
#   ('4-10', 1.5),
#   ('boo', 1.0),
#   ('4-10', 2.0),
#   ('CM', 1.0),
#   ('1', 2.0),
#   ('2-3', 1.0),
#   ('11-25', 2.0),
#   ('1', 0.5),
#   ('boo', 1.5),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Kevin Na': [('11-25', 1.5),
#   ('11-25', 1.5),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('1', 0.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('2-3', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0)],
#  'Keegan Bradley': [('CM', 1.5),
#   ('1', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('CM', 2.0),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('4-10', 1.5),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Brooks Koepka': [('CM', 1.5),
#   ('11-25', 1.5),
#   ('11-25', 0.5),
#   ('4-10', 1.0),
#   ('1', 2.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('11-25', 1.0),
#   ('1', 2.0),
#   ('CM', 1.0),
#   ('2-3', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0)],
#  'Patrick Reed': [('CM', 1.5),
#   ('11-25', 1.5),
#   ('CM', 0.5),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('4-10', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('4-10', 1.0),
#   ('1', 2.0),
#   ('4-10', 1.0),
#   ('4-10', 1.0),
#   ('2-3', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0)],
#  'Bubba Watson': [('CM', 1.5),
#   ('11-25', 1.5),
#   ('4-10', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('11-25', 0.5),
#   ('1', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('4-10', 2.0),
#   ('1', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.5),
#   ('1', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Phil Mickelson': [('CM', 1.5),
#   ('CM', 1.5),
#   ('11-25', 0.5),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.5),
#   ('4-10', 1.0),
#   ('CM', 2.0),
#   ('11-25', 0.5),
#   ('11-25', 1.0),
#   ('1', 1.5),
#   ('4-10', 1.0),
#   ('2-3', 1.0),
#   ('4-10', 1.0)],
#  'Andrew Putnam': [('11-25', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('2-3', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Jason Kokrak': [('11-25', 1.5),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('2-3', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Adam Hadwin': [('11-25', 1.5),
#   ('11-25', 0.5),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 1.5),
#   ('4-10', 1.0),
#   ('CM', 1.0)],
#  'Alex Noren': [('11-25', 1.5),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 2.0),
#   ('2-3', 0.5),
#   ('11-25', 1.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('2-3', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.5),
#   ('2-3', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0)],
#  'Charles Howell III': [('11-25', 1.5),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('boo', 2.0),
#   ('CM', 0.5),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 1.5),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('11-25', 0.5),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Henrik Stenson': [('CM', 1.5),
#   ('CM', 0.5),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('4-10', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.5),
#   ('4-10', 2.0),
#   ('4-10', 0.5),
#   ('4-10', 1.0),
#   ('boo', 1.0)],
#  'Austin Cook': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('4-10', 0.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Tyrrell Hatton': [('CM', 1.5),
#   ('11-25', 0.5),
#   ('11-25', 1.0),
#   ('4-10', 2.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('4-10', 2.0),
#   ('boo', 0.5),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('2-3', 1.5),
#   ('boo', 1.0)],
#  'Byeong Hun An': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('2-3', 1.0),
#   ('CM', 2.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('2-3', 1.0),
#   ('11-25', 0.5),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 1.0)],
#  'Beau Hossler': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 2.0),
#   ('2-3', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('2-3', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0)],
#  'Zach Johnson': [('CM', 1.5),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0)],
#  'Ted Potter Jr': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('1', 1.0)],
#  'Brice Garnett': [('CM', 1.5),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Andrew Landry': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'C.T. Pan': [('CM', 1.5),
#   ('4-10', 0.5),
#   ('CM', 1.0),
#   ('2-3', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Peter Uihlein': [('CM', 1.5),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Chez Reavie': [('CM', 1.5),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('CM', 2.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('2-3', 1.0),
#   ('2-3', 1.0)],
#  'Chris Kirk': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0)],
#  'Rafa Cabrera Bello': [('CM', 1.5),
#   ('4-10', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 2.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('4-10', 0.5),
#   ('11-25', 1.5),
#   ('CM', 2.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('2-3', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Siwoo Kim': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('2-3', 1.0),
#   ('11-25', 2.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Keith Mitchell': [('CM', 1.5),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('2-3', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('4-10', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'J.J Spaun': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('2-3', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Scott Piercy': [('CM', 1.5),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('11-25', 1.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Luke List': [('CM', 1.5),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('2-3', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('4-10', 1.0),
#   ('2-3', 1.0),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('2-3', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Brian Gay': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('4-10', 1.0)],
#  'Ian Poulter': [('CM', 1.5),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 0.5),
#   ('11-25', 1.5),
#   ('4-10', 1.0),
#   ('CM', 2.0),
#   ('1', 0.5),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Adam Scott': [('CM', 1.5),
#   ('CM', 0.5),
#   ('4-10', 1.0),
#   ('2-3', 2.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Ryan Armour': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Abraham Ancer': [('CM', 1.5),
#   ('4-10', 0.5),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('boo', 2.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('4-10', 0.5),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Jordan Spieth': [('CM', 1.5),
#   ('11-25', 0.5),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('4-10', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('2-3', 2.0),
#   ('2-3', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.5),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Pat Perez': [('CM', 1.5),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Louis Oosthuizen': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('11-25', 2.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('11-25', 1.0)],
#  'Kevin Kisner': [('CM', 1.5),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('2-3', 2.0),
#   ('CM', 0.5),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('CM', 2.0),
#   ('2-3', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Chesson Hadley': [('CM', 1.5),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.5),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0)],
#  'Emiliano Grillo': [('CM', 1.5),
#   ('4-10', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('2-3', 1.0),
#   ('CM', 1.5),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('2-3', 0.5),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0)],
#  'Brendan Steele': [('CM', 1.5),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.5),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0),
#   ('2-3', 1.0)],
#  'Ryan Palmer': [('CM', 1.5),
#   ('boo', 0.5),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Brandt Snedeker': [('CM', 1.5),
#   ('CM', 0.5),
#   ('1', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('boo', 2.0),
#   ('2-3', 0.5),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0)],
#  'Brian Harman': [('CM', 1.5),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 0.5),
#   ('4-10', 1.0),
#   ('CM', 2.0),
#   ('11-25', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.5),
#   ('CM', 1.0)],
#  'Brian Stuard': [('CM', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Kevin Chappell': [('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('4-10', 2.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.5),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0)],
#  'James Hahn': [('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0)],
#  'Daniel Berger': [('CM', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('4-10', 2.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0)],
#  'Kevin Tway': [('CM', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Branden Grace': [('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('4-10', 0.5),
#   ('2-3', 1.0),
#   ('CM', 1.5),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0)],
#  'Russell Knox': [('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('1', 1.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Matt Kuchar': [('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('4-10', 2.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.5),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('4-10', 0.5),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0)],
#  'J.B. Holmes': [('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('2-3', 1.0),
#   ('2-3', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Danny Lee': [('CM', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Scott Stallings': [('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 1.0)],
#  'Bronson Burgoon': [('CM', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('2-3', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Russell Henley': [('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('boo', 2.0),
#   ('4-10', 0.5),
#   ('4-10', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('11-25', 2.0),
#   ('4-10', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Stewart Cink': [('CM', 0.5),
#   ('boo', 1.0),
#   ('4-10', 2.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('2-3', 1.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Nick Watney': [('CM', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('2-3', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Tom Hoge': [('CM', 0.5),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Jimmy Walker': [('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 0.5),
#   ('CM', 2.0),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('2-3', 1.5),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('4-10', 1.0)],
#  'Ryan Moore': [('CM', 0.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('CM', 2.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('boo', 1.0)],
#  'Charley Hoffman': [('CM', 0.5),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('11-25', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Meenwhee Kim': [('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('2-3', 1.0),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Jamie Lovemark': [('CM', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.5),
#   ('boo', 1.0),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Jhonattan Vegas': [('boo', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Kelly Kraft': [('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('2-3', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Troy Merritt': [('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0)],
#  'Ollie Schniederjans': [('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('2-3', 1.0)],
#  'Anirban Lahiri': [('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('boo', 2.0),
#   ('CM', 0.5),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Michael Kim': [('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 2.0),
#   ('1', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Satoshi Kodaira': [('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('1', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5)],
#  'Joel Dahmen': [('boo', 0.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('2-3', 1.0),
#   ('4-10', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Kevin Streelman': [('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0)],
#  'Jason Dufner': [('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 2.0),
#   ('11-25', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('4-10', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('11-25', 1.0)],
#  'Sam Ryder': [('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('2-3', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('4-10', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  "Sean O'Hair": [('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Seamus Power': [('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Harold Varner III': [('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 1.0),
#   ('4-10', 0.5),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('4-10', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Alex Cejka': [('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Trey Mullinax': [('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0)],
#  'Brandon Harkins': [('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Sam Saunders': [('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('4-10', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Martin Laird': [('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('4-10', 1.0)],
#  'Sunghoon Kang': [('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Nick Taylor': [('boo', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Charl Schwartzel': [('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('2-3', 1.5),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0)],
#  'John Huh': [('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Vaughn Taylor': [('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0)],
#  'Scott Brown': [('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Harris English': [('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Rory Sabbatini': [('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Ryan Blaum': [('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Tyler Duncan(Jul1989)': [('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Richy Werenski': [('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'JT Poston': [('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'William McGirt': [('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Grayson Murray': [('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0)],
#  'Jim Furyk': [('4-10', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'D.A. Points': [('4-10', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'David Hearn': [('4-10', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Michael Thompson': [('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 0.5),
#   ('11-25', 1.0)],
#  'John Oda': [('11-25', 1.0), ('boo', 1.0)],
#  'Brett Stegmaier': [('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0)],
#  'Doug Ghim': [('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('CM', 2.0)],
#  'Shawn Stefani': [('11-25', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Peter Malnati': [('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Patrick Rodgers': [('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('boo', 1.0)],
#  'Sergio Garcia': [('11-25', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('boo', 2.0),
#   ('4-10', 1.0),
#   ('4-10', 1.0),
#   ('4-10', 1.5),
#   ('CM', 1.0)],
#  'Jonathan Byrd': [('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0)],
#  'Aaron Baddeley': [('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Cameron Percy': [('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Johnson Wagner': [('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0)],
#  'Joaquin Niemann': [('CM', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 0.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('4-10', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0)],
#  'Matthew Fitzpatrick': [('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('11-25', 2.0),
#   ('4-10', 0.5),
#   ('CM', 1.5),
#   ('11-25', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5)],
#  'Jonas Blixt': [('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Denny McCarthy': [('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Dylan Meyer': [('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 2.0),
#   ('CM', 1.0)],
#  'Billy Hurley III': [('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Julian Suri': [('CM', 1.0),
#   ('11-25', 2.0),
#   ('CM', 2.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('4-10', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Blayne Barber': [('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Corey Conners': [('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Sangmoon Bae': [('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Bill Haas': [('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Roberto Diaz': [('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Lanto Griffin': [('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Graeme McDowell': [('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Martin Flores': [('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0)],
#  'Hudson Swafford': [('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Mackenzie Hughes': [('CM', 1.0),
#   ('4-10', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 0.5),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Conrad Shindler': [('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Stephan Jaeger': [('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Zhang Xinjun': [('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Ricky Barnes': [('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Jason Bohn': [('boo', 1.0), ('CM', 1.0), ('boo', 1.0)],
#  'Arjun Atwal': [('boo', 1.0), ('CM', 1.0)],
#  'Ernie Els': [('boo', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Stuart Appleby': [('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Tyrone van Aswegen': [('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Martin Piller': [('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Shane Lowry': [('boo', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 0.5),
#   ('CM', 1.5),
#   ('CM', 1.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Nicholas Lindheim': [('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'T.J. Vogel': [('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'Marty Dou Zecheng': [('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Will Zalatoris': [('boo', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Michael DeMorat': [('boo', 1.0), ('CM', 2.0)],
#  'Norman Xiong': [('boo', 1.0), ('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Ben Crane': [('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('4-10', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Davis Love III': [('boo', 1.0),
#   ('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Steve Stricker': [('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 2.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.5),
#   ('boo', 0.5),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'David Lingmerth': [('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Andrew Yun': [('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Talor Gooch': [('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
# ...
#  'Rhys Enoch': [('CM', 2.0)],
#  'Sam Locke': [('CM', 2.0)],
#  'Fabrizio Zanotti': [('boo', 2.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 0.5)],
#  'George Coetzee': [('boo', 2.0), ('boo', 1.0), ('11-25', 1.0), ('boo', 0.5)],
#  'Tom Lehman': [('boo', 2.0)],
#  'Oliver Wilson': [('boo', 2.0)],
#  'Nicolai Hojgaard(Am)': [('boo', 2.0)],
#  'Marcus Armitage': [('boo', 2.0)],
#  'Scott Jamieson': [('boo', 2.0), ('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Mark Calcavecchia': [('boo', 2.0)],
#  'Sanghyun Park': [('boo', 2.0)],
#  'Jazz Janewattananond': [('boo', 2.0)],
#  'Thomas Curtis': [('boo', 2.0)],
#  'Haraldur Magnus': [('boo', 2.0)],
#  'Hideto Tanihara': [('boo', 2.0), ('CM', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Shota Akiyoshi': [('boo', 2.0), ('boo', 2.0)],
#  'Michael Hendry': [('boo', 2.0)],
#  'Sandy Lyle': [('boo', 2.0), ('boo', 2.0)],
#  'Todd Hamilton': [('boo', 2.0)],
#  'Danthai Boonma': [('boo', 2.0)],
#  'Minchel Choi': [('boo', 2.0)],
#  'Grant Forrest': [('boo', 2.0)],
#  'Nicolas Colsaerts': [('boo', 2.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 0.5)],
#  'Lin YuxinAm)': [('boo', 2.0), ('boo', 2.0)],
#  'Brady Schnell': [('boo', 2.0)],
#  'Masanori Kobayashi': [('boo', 2.0)],
#  'Jack Senior': [('boo', 2.0)],
#  'Ashton Turner': [('boo', 2.0)],
#  'James Robinson': [('boo', 2.0)],
#  'Jens Dantorp': [('boo', 2.0), ('2-3', 1.0), ('CM', 1.0), ('CM', 0.5)],
#  'Jovan Rebula(Am)': [('boo', 2.0)],
#  'Darren Clarke': [('boo', 2.0), ('boo', 1.0), ('boo', 1.0)],
#  'David Duval': [('boo', 2.0), ('boo', 1.0), ('boo', 1.0)],
#  'Trevor Immelman': [('2-3', 1.0), ('boo', 1.0), ('CM', 0.5), ('boo', 2.0)],
#  'Dean Burmester': [('4-10', 1.0),
#   ('CM', 1.0),
#   ('CM', 2.0),
#   ('11-25', 0.5),
#   ('CM', 1.5)],
#  'Aaron Rai': [('4-10', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Stephen Gallacher': [('4-10', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Marcel Siem': [('11-25', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Richard Sterne': [('11-25', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Scott Hend': [('11-25', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Andrea Pavan': [('11-25', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Sam Horsfield': [('11-25', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 0.5),
#   ('11-25', 1.0)],
#  'Justin Walters': [('11-25', 1.0), ('boo', 1.0)],
#  'Joakim Lagergren': [('11-25', 1.0), ('11-25', 1.0), ('boo', 0.5)],
#  'Rakhyun Cho': [('CM', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Connor Syme': [('CM', 1.0), ('boo', 1.0)],
#  'Thongchai Jaidee': [('CM', 1.0), ('CM', 1.0), ('4-10', 0.5)],
#  'Gonzalo Fdez-Castano': [('CM', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'James Morrison': [('CM', 1.0), ('CM', 1.0), ('boo', 2.0), ('boo', 0.5)],
#  'Steven Brown': [('CM', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Ricardo Gouveia': [('CM', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Oliver Fisher': [('CM', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Christiaan Bezuidenhout': [('CM', 1.0), ('11-25', 1.0)],
#  'Darren Fichardt': [('CM', 1.0), ('CM', 1.0), ('4-10', 0.5)],
#  'Soren Kjeldsen': [('CM', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Matthieu Pavon': [('CM', 1.0), ('4-10', 1.0), ('11-25', 2.0), ('CM', 0.5)],
#  'Jinho Choi': [('CM', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Robert Karlsson': [('CM', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Robert Rock': [('CM', 1.0), ('CM', 1.0), ('11-25', 0.5)],
#  'Benjamin Hebert': [('CM', 1.0), ('CM', 1.0), ('CM', 0.5)],
#  'Oliver Farr': [('CM', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Lorenzo Gagli': [('CM', 1.0), ('boo', 1.0)],
#  'Julien Guerrier': [('CM', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Jamie McLeary': [('CM', 1.0)],
#  'Clement Sordet': [('CM', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Scott Fernandez': [('CM', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Duncan Stewart': [('CM', 1.0)],
#  'Pedro Oriol': [('CM', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Thomas Detry': [('CM', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Adam Bland': [('CM', 1.0), ('CM', 1.0), ('boo', 0.5), ('11-25', 1.5)],
#  'Lasse Jensen': [('boo', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'David Horsey': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Matteo Manassero': [('boo', 1.0), ('CM', 1.0), ('CM', 0.5)],
#  'Lucas Bjerregaard': [('boo', 1.0), ('boo', 1.0), ('2-3', 0.5)],
#  'Edoardo Molinari': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Bradley Dredge': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Peter Hanson': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Soomin Lee': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Nacho Elvira': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Jeff Winther': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Chris Paisley': [('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.5)],
#  'Jacques Kruyswijk': [('boo', 1.0), ('boo', 1.0), ('11-25', 0.5)],
#  'Richie Ramsay': [('boo', 1.0), ('CM', 1.0), ('boo', 2.0), ('CM', 0.5)],
#  'Wu Ashun': [('boo', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Charlie Ford': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Laurie Canter': [('boo', 1.0), ('boo', 1.0)],
#  'Jason Scrivener': [('boo', 1.0), ('boo', 1.0), ('boo', 2.0), ('boo', 0.5)],
#  'Tapio Pulkkanen': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Chris Hanson': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Bradley Neil': [('boo', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Haydn Porteous': [('boo', 1.0), ('CM', 1.0), ('CM', 0.5)],
#  'Marc Warren': [('boo', 1.0), ('CM', 1.0), ('CM', 0.5)],
#  'Peter Whiteford': [('boo', 1.0)],
#  'Andrew Dodt': [('boo', 1.0), ('CM', 1.0), ('CM', 0.5)],
#  'Raphael Jacquelin': [('boo', 1.0), ('4-10', 1.0), ('boo', 0.5)],
#  'David Howell': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Gregory Havret': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Richard Bland': [('boo', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Lee Slattery': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'David Drysdale': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Daniel Im': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Ashley Chesters': [('boo', 1.0), ('11-25', 1.0), ('boo', 0.5)],
#  'Jeunghun Wang': [('boo', 1.0), ('CM', 1.0), ('CM', 0.5)],
#  'Chase Koepka': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Alvaro Quiros': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'S.S.P. Chawrasia': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Adrien Saddier': [('boo', 1.0), ('11-25', 1.0), ('CM', 0.5)],
#  'Nino Bertasio': [('boo', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Ryan Evans': [('boo', 1.0), ('boo', 1.0), ('boo', 2.0), ('boo', 0.5)],
#  'Matthias Schwab': [('boo', 1.0), ('boo', 1.0)],
#  'Sebastien Gros': [('boo', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Thomas Bjorn': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Matthew Baldwin': [('boo', 1.0), ('boo', 1.0)],
#  'Daniel Brooks': [('boo', 1.0), ('CM', 1.0), ('CM', 0.5)],
#  'Paul Waring': [('boo', 1.0), ('CM', 1.0), ('boo', 2.0), ('CM', 0.5)],
#  'Romain Wattel': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Callum Shinkwin': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Renato Paratore': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Gregory Bourdy': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Mikko Ilonen': [('boo', 1.0), ('11-25', 1.0), ('boo', 0.5)],
#  'Thomas Aiken': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Sam Brazel': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Jamie Donaldson': [('boo', 1.0), ('boo', 0.5)],
#  'Pablo Larrazabal': [('boo', 1.0), ('CM', 1.0), ('boo', 0.5)],
#  'Carlos Pigem': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  "Conor O'Neil": [('boo', 1.0)],
#  'David Lipsky': [('boo', 1.0), ('boo', 1.0), ('CM', 0.5), ('CM', 1.5)],
#  'Jason Norris': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Maximilian Kieffer': [('boo', 1.0), ('boo', 1.0), ('CM', 0.5)],
#  'Phachara Khongwatmai': [('boo', 1.0), ('boo', 1.0), ('boo', 0.5)],
#  'Nick Hardy(am)': [('CM', 1.0), ('CM', 1.0)],
#  'Mark Wilson': [('CM', 1.0), ('boo', 1.0), ('CM', 1.0)],
#  'D.J. Trahan': [('CM', 1.0), ('boo', 1.0), ('boo', 1.0)],
#  'Tim Herron': [('boo', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Manav Shah': [('boo', 1.0)],
#  'Charlie Wi': [('boo', 1.0)],
#  'Dru Love IV': [('boo', 1.0), ('boo', 1.0), ('boo', 1.0)],
#  'Broc Everett': [('boo', 1.0)],
#  'Charlie Beljan': [('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Vince India': [('boo', 1.0)],
#  'Steven Bowditch': [('boo', 1.0), ('boo', 0.5), ('boo', 1.0)],
#  'Troy Matteson': [('boo', 1.0), ('boo', 0.5), ('boo', 1.0), ('boo', 1.0)],
#  'Robert Allenby': [('boo', 1.0), ('boo', 0.5), ('boo', 1.0), ('CM', 1.0)],
#  'Daniel Chopra': [('boo', 1.0), ('boo', 1.0), ('boo', 1.0)],
#  'Chris Couch': [('boo', 1.0), ('boo', 0.5), ('boo', 1.0), ('CM', 1.0)],
#  'John Rollins': [('boo', 1.0), ('boo', 1.0), ('boo', 1.0)],
#  'Brian Bullington': [('boo', 1.0)],
#  'Brendon Todd': [('boo', 1.0), ('boo', 1.0)],
#  'Craig Barlow': [('boo', 1.0)],
#  'Chad Proehl': [('boo', 1.0)],
#  'David Berganio-Jr': [('boo', 1.0), ('boo', 1.0), ('boo', 1.0)],
#  'Jason Gore': [('boo', 1.0), ('boo', 0.5)],
#  'Cameron Beckman': [('boo', 1.0), ('boo', 1.0), ('boo', 1.0)],
#  'Matthew Nixon': [('11-25', 1.0)],
#  'Simon Thornton': [('CM', 1.0)],
#  'Felipe Aguilar': [('CM', 1.0)],
#  'Gavin Moynihan': [('boo', 1.0)],
#  'Ruaidhri McGee': [('boo', 1.0)],
#  'Cormac Sharvin': [('boo', 1.0)],
#  'Mark Foster': [('boo', 1.0)],
#  'Paul McGinley': [('boo', 1.0)],
#  'Colm Moriarty': [('boo', 1.0)],
#  'Nicolas Geyger': [('boo', 1.0)],
#  'Christofer Blomstrand': [('boo', 1.0)],
#  'Cian McNamara': [('boo', 1.0)],
#  "Neil O'Briain": [('boo', 1.0)],
#  'Marcus Fraser': [('boo', 1.0), ('boo', 0.5)],
#  'Henric Sturehed': [('boo', 1.0)],
#  'John Peterson': [('11-25', 0.5), ('CM', 1.0), ('CM', 1.0), ('CM', 1.0)],
#  'Steve Marino': [('CM', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Chase Seiffert': [('boo', 0.5), ('4-10', 1.0)],
#  'Wes Homan': [('boo', 0.5)],
#  'David S Bradshaw': [('boo', 0.5)],
#  'Bob Estes': [('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Blake Taylor': [('boo', 0.5)],
#  'Logan Lagodich': [('boo', 0.5)],
#  'Davey Jude': [('boo', 0.5)],
#  'Jon Curran': [('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  "Sam O'Dell": [('boo', 0.5)],
#  'Geoff Ogilvy': [('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Devin Gee': [('boo', 0.5)],
#  'Smylie Kaufman': [('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Ben Martin': [('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0)],
#  'Andrew Svoboda': [('boo', 1.0)],
#  'Rick Lamb': [('boo', 1.0), ('boo', 1.0), ('boo', 1.0), ('boo', 1.0)],
#  "Adam D'Amario": [('boo', 1.0)],
#  'Sam Burns': [('CM', 2.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('4-10', 1.0)],
#  'Tim Wilkinson': [('CM', 2.0)],
#  'Matt Parziale': [('CM', 2.0), ('boo', 2.0)],
#  'Luis Gagne': [('CM', 2.0)],
#  'Chris Naegel': [('CM', 2.0)],
#  'Calum Hill(Nov1994)': [('CM', 2.0)],
#  'Andrew Johnston': [('CM', 2.0), ('boo', 0.5)],
#  'Cameron Wilson': [('CM', 2.0)],
#  'Will Grimmer': [('CM', 2.0)],
#  'Braden Thornberry': [('boo', 2.0), ('CM', 1.0)],
#  'Roberto Castro': [('boo', 2.0)],
#  'Lucas Glover': [('boo', 2.0),
#   ('CM', 1.0),
#   ('CM', 1.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('CM', 0.5),
#   ('CM', 1.0),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'Eric Axley': [('boo', 2.0), ('boo', 1.0), ('CM', 1.0), ('CM', 1.0)],
#  'Sebastian Vazquez': [('boo', 2.0)],
#  'Ty Strafaci': [('boo', 2.0), ('boo', 1.0)],
#  'Juan Sebastian Munoz': [('boo', 2.0)],
#  'Cole Miller': [('boo', 2.0)],
#  'Sungjoon Park': [('boo', 2.0)],
#  'David Bransdon': [('boo', 2.0)],
#  'Chris Babcock': [('boo', 2.0)],
#  'Michael Putnam': [('boo', 2.0)],
#  'Rhett Rasmussen': [('boo', 2.0)],
#  'Michael Miller(1992)': [('boo', 2.0)],
#  'Stewart Hagestad(Am)': [('boo', 2.0)],
#  'Liang Wenchong': [('boo', 2.0)],
#  'Jacob Bergeron': [('boo', 2.0)],
#  'Theo Humphrey(Am)': [('boo', 2.0)],
#  'Yu Chun-an(am)': [('boo', 2.0)],
#  'David Gazzolo': [('boo', 2.0)],
#  'Rikuya Hoshino': [('boo', 2.0)],
#  'Kristoffer Reitan': [('boo', 2.0)],
#  'Kenny Perry': [('boo', 2.0), ('boo', 1.0)],
#  'Garrett Rank': [('boo', 2.0)],
#  'Franklin Huang(Am)': [('boo', 2.0)],
#  'Ryan Lumsden(Am)': [('boo', 2.0)],
#  'Timothy Wiseman': [('boo', 2.0)],
#  'Noah Goodwin': [('boo', 2.0), ('boo', 1.0)],
#  'Shintaro Ban(Am)': [('boo', 2.0)],
#  'Harry Ellis': [('boo', 2.0), ('boo', 1.0), ('boo', 2.0)],
#  'Sulman Raza': [('boo', 2.0)],
#  'Michael Hebert': [('boo', 2.0)],
#  'Philip Barbaree': [('boo', 2.0)],
#  'Scott Gregory': [('boo', 2.0)],
#  'Nate Lashley': [('CM', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('11-25', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Scottie Scheffler(Am)': [('CM', 1.0), ('boo', 1.0)],
#  'A.J. McInerney': [('CM', 1.0), ('boo', 1.0)],
#  'Grant Hirschman': [('CM', 1.0)],
#  'Casey Wittenberg': [('CM', 1.0)],
#  'Ben Crancer': [('boo', 1.0)],
#  'Zachary Olsen': [('boo', 1.0)],
#  'Dawson Armstrong': [('boo', 1.0)],
#  'Greg Chalmers': [('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('CM', 0.5),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0)],
#  'Andrew Dorn': [('CM', 1.0)],
#  'Bud Cauley': [('boo', 1.0),
#   ('boo', 1.5),
#   ('CM', 1.0),
#   ('11-25', 1.0),
#   ('11-25', 0.5),
#   ('11-25', 1.0),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('11-25', 1.0),
#   ('boo', 1.0)],
#  'K.J. Choi': [('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 0.5),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Maverick McNealy': [('CM', 1.0), ('CM', 1.0), ('boo', 1.0)],
#  'Keith Clearwater': [('boo', 1.0)],
#  'James Heath': [('CM', 0.5)],
#  'Joost Luiten': [('boo', 0.5), ('CM', 1.5)],
#  "Paul O'Hara": [('boo', 0.5)],
#  'Robert Coles': [('boo', 0.5)],
#  'Richard Wallis': [('boo', 0.5)],
#  'Gavin Hay': [('boo', 0.5)],
#  'Oliver Goss': [('boo', 1.0)],
#  'Angel Cabrera': [('boo', 1.0), ('boo', 2.0), ('boo', 1.0)],
#  'Steven Ihm': [('boo', 1.0)],
#  'Ryan Baca': [('boo', 1.0), ('boo', 0.5)],
#  'Tom Whitney': [('boo', 1.0)],
#  'Brian Norman': [('boo', 1.0)],
#  'Scott McCarron': [('boo', 1.5)],
#  'Derek Ernst': [('boo', 1.0), ('boo', 1.0)],
#  'Ryan Ruffels': [('boo', 1.0)],
#  'Carter Jenkins': [('boo', 1.0)],
#  'J.T. Griffin': [('boo', 1.0)],
#  'Guillermo Pereira': [('boo', 1.0)],
#  'Luke Donald': [('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0)],
#  'Philip Knowles': [('boo', 1.0)],
#  'Colt Knost': [('boo', 1.0), ('boo', 1.0), ('boo', 1.0), ('CM', 1.0)],
#  'Glen Day': [('boo', 1.0)],
#  'Jeff Maggert': [('boo', 1.0)],
#  'Steve Scott': [('boo', 1.0)],
#  'Bernd Wiesberger': [('11-25', 2.0), ('CM', 1.0), ('CM', 1.5), ('boo', 1.0)],
#  'Fred Couples': [('CM', 2.0)],
#  'Jose M Olazabal': [('boo', 2.0)],
#  'Ian Woosnam': [('boo', 2.0)],
#  'Larry Mize': [('boo', 2.0)],
#  "Mark O'Meara": [('boo', 2.0)],
#  'Bobby Gates': [('CM', 0.5)],
#  'Dawie van der Walt': [('CM', 0.5)],
#  'Andrew Loupe': [('boo', 0.5), ('boo', 1.0), ('boo', 1.0)],
#  'Zach Cabra': [('boo', 0.5)],
#  'Camilo Villegas': [('boo', 0.5),
#   ('boo', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0),
#   ('boo', 1.0),
#   ('CM', 1.0)],
#  'JJ Wood': [('boo', 0.5)],
#  'Curtis Luck': [('CM', 1.0)],
#  'Collin Morikawa(Am)': [('CM', 1.0)],
#  'Paul Goydos': [('CM', 1.0)],
#  'Robert Gamez': [('boo', 1.0)],
#  'Donny Lee': [('boo', 1.0)],
#  'Jimmy Stanger': [('boo', 1.0)],
#  'Jack Maguire': [('boo', 1.0)],
#  'Rod Perry': [('boo', 1.0)],
#  'Morgan Hoffmann': [('CM', 1.0), ('boo', 1.0), ('boo', 1.0)],
#  'Andrew Novak': [('CM', 1.0)],
#  'Jhared Hack': [('boo', 1.0)],
#  'Andrew Filbert': [('boo', 1.0)],
#  'Richard H. Lee': [('boo', 1.0), ('boo', 1.0)],
#  'Seunghyuk Kim': [('boo', 1.0)],
#  'Vinnie Poncino': [('boo', 1.0)],
#  'Jim Herman': [('boo', 1.0), ('boo', 1.0)],
#  'Jerry Kelly': [('boo', 1.0)],
#  'Peter Jacobsen': [('boo', 1.0)],
#  'David Solomon': [('boo', 1.0)],
#  'Wyndham Clark': [('boo', 1.0)],
#  'Jesse Mueller': [('boo', 1.0)]}
